# %%
! pip install gdown
! gdown --no-check-certificate --folder 'https://drive.google.com/drive/folders/1OhNOXveVDasgQcjurKxJ2-Q8hhH9JxY8?usp=sharing'
# Out:
# Requirement already satisfied: gdown in /usr/local/lib/python3.10/dist-packages (4.6.6)
# Requirement already satisfied: filelock in /usr/local/lib/python3.10/dist-packages (from gdown) (3.13.1)
# Requirement already satisfied: requests[socks] in /usr/local/lib/python3.10/dist-packages (from gdown) (2.31.0)
# Requirement already satisfied: six in /usr/local/lib/python3.10/dist-packages (from gdown) (1.16.0)
# Requirement already satisfied: tqdm in /usr/local/lib/python3.10/dist-packages (from gdown) (4.66.1)
# Requirement already satisfied: beautifulsoup4 in /usr/local/lib/python3.10/dist-packages (from gdown) (4.11.2)
# Requirement already satisfied: soupsieve>1.2 in /usr/local/lib/python3.10/dist-packages (from beautifulsoup4->gdown) (2.5)
# Requirement already satisfied: charset-normalizer<4,>=2 in /usr/local/lib/python3.10/dist-packages (from requests[socks]->gdown) (3.3.2)
# Requirement already satisfied: idna<4,>=2.5 in /usr/local/lib/python3.10/dist-packages (from requests[socks]->gdown) (3.6)
# Requirement already satisfied: urllib3<3,>=1.21.1 in /usr/local/lib/python3.10/dist-packages (from requests[socks]->gdown) (2.0.7)
# Requirement already satisfied: certifi>=2017.4.17 in /usr/local/lib/python3.10/dist-packages (from requests[socks]->gdown) (2023.11.17)
# Requirement already satisfied: PySocks!=1.5.7,>=1.5.6 in /usr/local/lib/python3.10/dist-packages (from requests[socks]->gdown) (1.7.1)
# Retrieving folder list
# /usr/local/lib/python3.10/dist-packages/urllib3/connectionpool.py:1100: InsecureRequestWarning: Unverified HTTPS request is being made to host 'drive.google.com'. Adding certificate verification is strongly advised. See: https://urllib3.readthedocs.io/en/latest/advanced-usage.html#tls-warnings
#   warnings.warn(
# Processing file 1KXCLKv2W4Es_f0ULarQjpdUNG51WEVhe shuffled_news.csv
# Retrieving folder list completed
# Building directory structure
# Building directory structure completed
# /usr/local/lib/python3.10/dist-packages/urllib3/connectionpool.py:1100: InsecureRequestWarning: Unverified HTTPS request is being made to host 'drive.google.com'. Adding certificate verification is strongly advised. See: https://urllib3.readthedocs.io/en/latest/advanced-usage.html#tls-warnings
#   warnings.warn(
# /usr/local/lib/python3.10/dist-packages/urllib3/connectionpool.py:1100: InsecureRequestWarning: Unverified HTTPS request is being made to host 'doc-0s-bc-docs.googleusercontent.com'. Adding certificate verification is strongly advised. See: https://urllib3.readthedocs.io/en/latest/advanced-usage.html#tls-warnings
#   warnings.warn(
# Downloading...
# From: https://drive.google.com/uc?id=1KXCLKv2W4Es_f0ULarQjpdUNG51WEVhe
# To: /content/data/shuffled_news.csv
# 100% 15.0M/15.0M [00:00<00:00, 116MB/s]
# Download completed

# %%
import pandas as pd
from sklearn.model_selection import train_test_split
import re

# %%
# !pip install hazm
# Out:
# Collecting hazm
#   Downloading hazm-0.9.4-py3-none-any.whl (371 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 371.7/371.7 kB 3.2 MB/s eta 0:00:00
# Collecting fasttext-wheel<0.10.0,>=0.9.2 (from hazm)
#   Downloading fasttext_wheel-0.9.2-cp310-cp310-manylinux_2_17_x86_64.manylinux2014_x86_64.whl (4.4 MB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 4.4/4.4 MB 35.1 MB/s eta 0:00:00
# Collecting flashtext<3.0,>=2.7 (from hazm)
#   Downloading flashtext-2.7.tar.gz (14 kB)
#   Preparing metadata (setup.py) ... done
# Requirement already satisfied: gensim<5.0.0,>=4.3.1 in /usr/local/lib/python3.10/dist-packages (from hazm) (4.3.2)
# Requirement already satisfied: nltk<4.0.0,>=3.8.1 in /usr/local/lib/python3.10/dist-packages (from hazm) (3.8.1)
# Collecting numpy==1.24.3 (from hazm)
#   Downloading numpy-1.24.3-cp310-cp310-manylinux_2_17_x86_64.manylinux2014_x86_64.whl (17.3 MB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 17.3/17.3 MB 50.2 MB/s eta 0:00:00
# Collecting python-crfsuite<0.10.0,>=0.9.9 (from hazm)
#   Downloading python_crfsuite-0.9.9-cp310-cp310-manylinux_2_17_x86_64.manylinux2014_x86_64.whl (993 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 993.5/993.5 kB 79.8 MB/s eta 0:00:00
# Requirement already satisfied: scikit-learn<2.0.0,>=1.2.2 in /usr/local/lib/python3.10/dist-packages (from hazm) (1.2.2)
# Collecting pybind11>=2.2 (from fasttext-wheel<0.10.0,>=0.9.2->hazm)
#   Downloading pybind11-2.11.1-py3-none-any.whl (227 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 227.7/227.7 kB 31.2 MB/s eta 0:00:00
# Requirement already satisfied: setuptools>=0.7.0 in /usr/local/lib/python3.10/dist-packages (from fasttext-wheel<0.10.0,>=0.9.2->hazm) (67.7.2)
# Requirement already satisfied: scipy>=1.7.0 in /usr/local/lib/python3.10/dist-packages (from gensim<5.0.0,>=4.3.1->hazm) (1.11.4)
# Requirement already satisfied: smart-open>=1.8.1 in /usr/local/lib/python3.10/dist-packages (from gensim<5.0.0,>=4.3.1->hazm) (6.4.0)
# Requirement already satisfied: click in /usr/local/lib/python3.10/dist-packages (from nltk<4.0.0,>=3.8.1->hazm) (8.1.7)
# Requirement already satisfied: joblib in /usr/local/lib/python3.10/dist-packages (from nltk<4.0.0,>=3.8.1->hazm) (1.3.2)
# Requirement already satisfied: regex>=2021.8.3 in /usr/local/lib/python3.10/dist-packages (from nltk<4.0.0,>=3.8.1->hazm) (2023.6.3)
# Requirement already satisfied: tqdm in /usr/local/lib/python3.10/dist-packages (from nltk<4.0.0,>=3.8.1->hazm) (4.66.1)
# Requirement already satisfied: threadpoolctl>=2.0.0 in /usr/local/lib/python3.10/dist-packages (from scikit-learn<2.0.0,>=1.2.2->hazm) (3.2.0)
# Building wheels for collected packages: flashtext
#   Building wheel for flashtext (setup.py) ... done
#   Created wheel for flashtext: filename=flashtext-2.7-py2.py3-none-any.whl size=9296 sha256=3c79aad88e627b408b8b36b1ce11825668697352da292011c8d5159d28d04101
#   Stored in directory: /root/.cache/pip/wheels/bc/be/39/c37ad168eb2ff644c9685f52554440372129450f0b8ed203dd
# Successfully built flashtext
# Installing collected packages: python-crfsuite, flashtext, pybind11, numpy, fasttext-wheel, hazm
#   Attempting uninstall: numpy
#     Found existing installation: numpy 1.23.5
#     Uninstalling numpy-1.23.5:
#       Successfully uninstalled numpy-1.23.5
# ERROR: pip's dependency resolver does not currently take into account all the packages that are installed. This behaviour is the source of the following dependency conflicts.
# lida 0.0.10 requires fastapi, which is not installed.
# lida 0.0.10 requires kaleido, which is not installed.
# lida 0.0.10 requires python-multipart, which is not installed.
# lida 0.0.10 requires uvicorn, which is not installed.
# Successfully installed fasttext-wheel-0.9.2 flashtext-2.7 hazm-0.9.4 numpy-1.24.3 pybind11-2.11.1 python-crfsuite-0.9.9

# %%
from hazm import Normalizer, WordTokenizer, stopwords_list

# %%
class DataPreprocessor:
    def __init__(self):
        self.data = None
        self.normalizer = Normalizer()
        self.tokenizer = WordTokenizer()
        self.stop_words = stopwords_list()

    def read_data(self, file_path):
        self.data = pd.read_csv(file_path)

    def split_data(self, test_size=0.2):

        X = self.data['Text']
        y = self.data['Topic']
        X_train, X_test, y_train, y_test = train_test_split(X, y, test_size=test_size, random_state=42)
        return X_train, X_test, y_train, y_test

    def clean_text(self, text):
        text = re.sub(r'[a-zA-Z0-9۰-۹;:.,،()«»]+', '', text)

        text = self.normalizer.normalize(text)
        tokens = self.tokenizer.tokenize(text)
        cleaned_text = ' '.join([token for token in tokens if token not in self.stop_words])

        return cleaned_text.strip()

# %%
#test
preprocessor = DataPreprocessor()
cleaned_text_example = preprocessor.clean_text(' این یک تست برای کلمات ایست در زبان فارسی است')
print(cleaned_text_example)
# Out:
# تست کلمات ایست زبان فارسی

# %%
from collections import defaultdict, Counter
from math import log
from sklearn.metrics import classification_report, accuracy_score, confusion_matrix

# %%
class NaiveBayesClassifier:
    def __init__(self):
        self.word_counts = defaultdict(lambda: defaultdict(int))
        self.class_counts = defaultdict(int)
        self.total_words = defaultdict(int)
        self.vocab = set()
        self.class_log_prior = defaultdict(float)
        self.word_log_prob = defaultdict(lambda: defaultdict(float))

    def count_word_per_class(self, data):
        for _, row in data.iterrows():
            cls = row['Topic']
            words = row['Text'].split()
            self.class_counts[cls] += 1
            for word in words:
                self.word_counts[cls][word] += 1
                self.vocab.add(word)

        for cls in self.word_counts:
            self.total_words[cls] = sum(self.word_counts[cls].values())
            unique_words_count = len(self.word_counts[cls])
            print(f"Class '{cls}' - Total Words: {self.total_words[cls]}, Unique Words: {unique_words_count}")
            most_common_words = Counter(self.word_counts[cls]).most_common(200)
            print(f"Top 200 words in class {cls}:")
            for word, count in most_common_words:
                print(f'{word}: {count}')
            print("\n")

    def calculate_word_log_prob_per_class(self):
        alpha = 1
        for cls in self.word_counts:
            total_words_in_class = self.total_words[cls]
            unique_words = len(self.vocab)
            for word in self.vocab:
                count = self.word_counts[cls][word]
                self.word_log_prob[cls][word] = log((count + alpha) / (total_words_in_class + alpha * unique_words))

    def calculate_log_prior(self):
        total_samples = sum(self.class_counts.values())
        for cls in self.class_counts:
            self.class_log_prior[cls] = log(self.class_counts[cls] / total_samples)

    def predict(self, text):
        words = text.split()
        scores = defaultdict(float)
        for cls in self.class_counts:
            scores[cls] = self.class_log_prior[cls]
            for word in words:
                if word in self.vocab:
                    scores[cls] += self.word_log_prob[cls][word]
        print("Scores per class:", scores)
        max_class = max(scores, key=scores.get)
        print("Predicted class:", max_class)
        return max_class

    def evaluate(self, true_labels, predicted_labels):
        cm = confusion_matrix(true_labels, predicted_labels)
        print("Confusion Matrix:\n", cm)

        accuracy = accuracy_score(true_labels, predicted_labels)
        print("Accuracy:", accuracy)

        report = classification_report(true_labels, predicted_labels)
        print(report)

# %%
preprocessor.read_data('/content/data/shuffled_news.csv')

# %%
X_train, X_test, y_train, y_test = train_test_split(preprocessor.data['Text'], preprocessor.data['Topic'], test_size=0.25)

# %%
X_train_clean = X_train.apply(preprocessor.clean_text)
X_test_clean = X_test.apply(preprocessor.clean_text)

# %%
classifier = NaiveBayesClassifier()
training_data = pd.DataFrame({'Text': X_train_clean, 'Topic': y_train})
classifier.count_word_per_class(training_data)
classifier.calculate_log_prior()
classifier.calculate_word_log_prob_per_class()
# Out:
# Class 'Tech' - Total Words: 231265, Unique Words: 5940
# Top 200 words in class Tech:
# فناوری: 2946
# شرکت: 2714
# محققان: 2005
# کشور: 1940
# تولید: 1841
# استفاده: 1822
# ارتباطات: 1593
# خبر: 1499
# ایران: 1456
# فضایی: 1431
# اطلاعات: 1414
# سال: 1297
# علمی: 1176
# توسعه: 1140
# سازمان: 1114
# دانش: 1075
# حوزه: 1043
# رئیس: 990
# دانشگاه: 982
# معاون: 950
# وزیر: 924
# موفق: 882
# بنیان: 849
# کرده‌اند: 843
# ملی: 821
# قرار: 814
# اینترنت: 805
# علوم: 802
# موبایل: 746
# برگزار: 732
# اعلام: 694
# مرکز: 662
# معاونت: 662
# ستاد: 655
# زمین: 627
# آمریکا: 625
# گوگل: 609
# بازار: 603
# نشان: 596
# نوآوری: 589
# شرکت‌های: 583
# دبیر: 562
# ابداع: 557
# ساخت: 555
# ارائه: 548
# هدف: 542
# بررسی: 536
# فناوری‌های: 513
# ایرانی: 504
# هزار: 486
# کاربران: 484
# شبکه: 478
# طراحی: 477
# منتشر: 476
# توسط: 474
# انجام: 474
# کار: 473
# میلیون: 471
# مصنوعی: 465
# همکاری: 461
# ایجاد: 460
# جمهوری: 459
# تهران: 456
# کمک: 451
# نام: 451
# مختلف: 449
# وزارت: 439
# جهان: 438
# پژوهشگاه: 431
# صنعت: 431
# همراه: 429
# شناسایی: 411
# حمایت: 407
# هوشمند: 404
# آب: 400
# ماهواره: 399
# بین‌المللی: 399
# روز: 398
# ماه: 397
# هفته: 396
# پژوهش: 388
# قصد: 383
# مجازی: 382
# نمایشگاه: 378
# رونمایی: 375
# محصولات: 371
# عرضه: 371
# میلیارد: 369
# فضای: 366
# دولت: 364
# تحقیقات: 361
# هوش: 360
# آینده: 358
# خودرو: 352
# مخابرات: 351
# صندوق: 350
# آغاز: 349
# طرح: 337
# مواد: 337
# علم: 336
# عنوان: 334
# شورای: 318
# پزشکی: 318
# ثبت: 316
# تجهیزات: 315
# شده‌اند: 315
# امنیت: 313
# مجهز: 312
# فضا: 312
# دستگاه: 309
# درصد: 304
# چینی: 304
# پژوهشگران: 302
# افزایش: 302
# خدمات: 301
# تاکید: 301
# رصد: 299
# جدیدی: 299
# سیستم: 299
# برتر: 295
# اپل: 294
# صورت: 293
# برقی: 290
# ریاست: 289
# بوک: 284
# حضور: 283
# میلادی: 283
# دلیل: 281
# ربات: 271
# گوشی: 268
# فیس: 266
# صنعتی: 262
# رئیس‌جمهور: 262
# کاهش: 254
# زیستی: 251
# تازگی: 248
# تلفن: 248
# مدیریت: 247
# آذرماه: 247
# ساخته‌شده: 247
# حرکت: 247
# بیماری: 246
# سرعت: 246
# انسان: 241
# راستای: 241
# طریق: 240
# کارت: 240
# پیشرفته: 236
# عضو: 236
# دانش‌بنیان: 235
# درمان: 232
# پژوهشی: 231
# اولیه: 231
# تجاری: 230
# بنیادی: 230
# قیمت: 229
# دستاوردهای: 229
# کشف: 229
# جمله: 226
# گوشی‌های: 226
# ارسال: 225
# مخابراتی: 224
# کسب: 223
# بومی: 220
# ایکس: 218
# محیط‌زیست: 216
# شهر: 214
# فعالیت: 214
# زیست‌فناوری: 214
# نسل: 214
# چین: 212
# دسترسی: 210
# ایستگاه: 210
# استان: 209
# قابلیت: 208
# جایزه: 208
# رویداد: 208
# تحقیقاتی: 208
# هشدار: 207
# اقتصاد: 207
# پروژه: 205
# اختلال: 205
# انرژی: 205
# مغز: 204
# آنلاین: 204
# آمریکایی: 203
# زمینه: 202
# مشکل: 202
# راه‌اندازی: 200
# پارک: 200
# کاربر: 200
# کنترل: 200
# وضعیت: 197
# جلوگیری: 197
# سلول‌های: 197
# اروپا: 197
# فناورانه: 196
# فعال: 196
# بودجه: 196
# اس: 195
#
#
# Class 'Sport' - Total Words: 215153, Unique Words: 3705
# Top 200 words in class Sport:
# تیم: 9743
# فوتبال: 6230
# ایران: 4774
# ملی: 4501
# لیگ: 3127
# جهانی: 2804
# جام: 2683
# فدراسیون: 2520
# دیدار: 2233
# مسابقات: 1938
# کشتی: 1892
# برتر: 1858
# سرمربی: 1765
# پرسپولیس: 1702
# حضور: 1667
# مرحله: 1639
# هفته: 1559
# بازی: 1516
# آسیا: 1428
# تیم‌های: 1363
# قهرمانی: 1331
# ورزش: 1186
# پیروزی: 1158
# عنوان: 1109
# بازیکنان: 1058
# کشور: 1055
# آزاد: 1039
# مقابل: 1022
# باشگاه: 1012
# نهایی: 1001
# بازیکن: 971
# اعلام: 946
# شکست: 945
# قطر: 937
# استقلال: 908
# جهان: 858
# جوانان: 856
# پایان: 853
# رئیس: 816
# برگزار: 782
# قهرمانان: 773
# برگزاری: 763
# فرنگی: 736
# رقابت‌های: 733
# والیبال: 706
# تهران: 687
# دست: 672
# سرپرست: 639
# رقابتهای: 637
# صعود: 631
# جدول: 605
# بین‌المللی: 597
# انتخاب: 589
# آمریکا: 585
# روز: 583
# ملی‌پوش: 578
# کمیته: 556
# فنی: 544
# صدر: 536
# وزارت: 529
# مهاجم: 528
# ولز: 523
# دوره: 523
# خبر: 517
# سال: 512
# مدال: 511
# نفر: 486
# علیرضا: 475
# فولاد: 462
# مردان: 461
# کشورمان: 457
# ایرانی: 452
# هندبال: 440
# دومین: 435
# بسکتبال: 428
# امروز: 427
# رسمی: 426
# فینال: 421
# ترکیب: 415
# نشان: 397
# عربستان: 396
# داور: 394
# دلیل: 393
# جایگاه: 388
# کسب: 387
# عملکرد: 381
# رقابت‌ها: 378
# اعضای: 378
# بانوان: 378
# کنفدراسیون: 377
# کارشناس: 377
# گرگان: 376
# موفق: 373
# ورزشکاران: 371
# حریفان: 366
# فرانسه: 365
# مربیان: 364
# قرار: 360
# گل: 357
# فوتسال: 356
# تمرین: 355
# نوجوانان: 353
# برد: 351
# گروه: 349
# اخراج: 349
# بگیرد: 347
# نفت: 346
# شهرداری: 345
# هشتم: 343
# مس: 341
# سابق: 337
# پیکان: 330
# وزیر: 328
# کادر: 326
# تاکید: 323
# پنجم: 322
# اسپانیا: 320
# باشگاه‌های: 319
# حذف: 319
# نتیجه: 318
# هند: 316
# بیست: 313
# مدافع: 312
# نماینده: 310
# مراسم: 305
# پیشین: 300
# ذوب‌آهن: 296
# النصر: 295
# احتمال: 289
# سر: 288
# بازگشت: 287
# دربی: 285
# خارجی: 284
# تکواندو: 284
# منصوب: 283
# درآمد: 283
# اشاره: 278
# چادرملو: 277
# فصل: 273
# قرارداد: 272
# اسامی: 272
# برنز: 269
# نساجی: 267
# آرژانتین: 266
# آغاز: 266
# کار: 262
# برتری: 262
# بازی‌های: 261
# مربی: 261
# ادامه: 261
# زنان: 260
# مازندران: 260
# رشته: 260
# ماه: 260
# رسانه: 258
# هواداران: 257
# تایید: 256
# دروازه‌بان: 253
# تنیس: 250
# مدعی: 248
# سپاهان: 248
# فردا: 246
# دریافت: 246
# ستاره: 242
# نیمه‌نهایی: 241
# تاریخ: 239
# جلسه: 239
# کاروان: 238
# انگلیس: 237
# وزنه‌برداری: 236
# اروپا: 232
# انتقاد: 231
# ورزشی: 231
# روسیه: 230
# آماده: 228
# تساوی: 227
# پیشنهاد: 225
# رد: 224
# کی‌روش: 218
# سیتی: 217
# زمین: 217
# قاره: 212
# شرایط: 212
# توسط: 211
# عمان: 211
# رفسنجان: 209
# تصمیمی: 208
# شورای: 207
# میز: 207
# تمدید: 207
# پرتغال: 206
# مالی: 204
# حکم: 203
# اشتباه: 202
# جمله: 201
# وضعیت: 200
# نیم‌فصل: 200
# باقی: 199
# واکنش: 197
# صحبت: 197
#
#
# Class 'Economy' - Total Words: 255139, Unique Words: 4830
# Top 200 words in class Economy:
# هزار: 3459
# کشور: 2863
# سال: 2408
# قیمت: 2317
# ایران: 2309
# سازمان: 2020
# وزیر: 1957
# افزایش: 1858
# تومان: 1838
# شرکت: 1778
# بانک: 1755
# نفت: 1734
# خبر: 1721
# درصد: 1696
# اعلام: 1688
# تولید: 1579
# بازار: 1566
# وزارت: 1509
# میلیون: 1474
# رئیس: 1464
# دولت: 1441
# امروز: 1433
# معاون: 1407
# مرکزی: 1372
# ارز: 1364
# کاهش: 1286
# کشاورزی: 1274
# تهران: 1273
# مسکن: 1203
# بودجه: 1201
# اقتصادی: 1187
# ملی: 1178
# میلیارد: 1139
# طرح: 1096
# ماه: 1029
# دلار: 1002
# گاز: 968
# آذر: 906
# نرخ: 903
# مدیرعامل: 865
# بورس: 794
# امور: 759
# توسعه: 733
# شهرسازی: 729
# آذرماه: 728
# صنعت: 703
# جهاد: 691
# معاملات: 687
# کرونا: 684
# واحد: 681
# آمریکا: 681
# امسال: 659
# آب: 651
# آینده: 650
# اقتصاد: 622
# گمرک: 602
# صادرات: 590
# گذشته: 590
# هفته: 580
# روز: 574
# استان: 572
# درصدی: 560
# صمت: 558
# فروش: 556
# مصرف: 555
# مجلس: 540
# برق: 535
# خرید: 535
# تامین: 531
# صورت: 528
# تجارت: 523
# تن: 522
# عرضه: 518
# برنامه: 514
# لایحه: 503
# نشان: 502
# شاخص: 493
# مرکز: 489
# کار: 483
# اساس: 481
# مدیرکل: 479
# مالی: 479
# تسهیلات: 477
# پایان: 471
# بانکی: 459
# بهار: 449
# مدیریت: 449
# سخنگوی: 445
# سامانه: 444
# توزیع: 442
# اوراق: 441
# اتحادیه: 441
# قرار: 439
# اجرای: 430
# اتاق: 423
# منابع: 418
# مقام: 417
# اشاره: 412
# یک‌میلیون: 411
# قانون: 410
# ماهه: 408
# پرداخت: 406
# تومانی: 404
# قطعه: 402
# اساسی: 399
# انرژی: 395
# ارزش: 390
# بیمه: 390
# مسئول: 388
# ستاد: 387
# محصولات: 387
# حوزه: 386
# مدیر: 378
# میزان: 377
# مرغ: 369
# رسمی: 367
# کالاهای: 366
# سرمایه: 360
# صنایع: 357
# سکه: 356
# آزادی: 356
# عضو: 353
# ساخت: 350
# حضور: 348
# آغاز: 345
# عنوان: 345
# واردات: 343
# ایجاد: 342
# تنظیم: 342
# استفاده: 338
# انجام: 336
# خودرو: 335
# انجمن: 325
# دولتی: 324
# کالا: 323
# مالیاتی: 322
# توجه: 321
# توسط: 320
# آزاد: 319
# تاکید: 317
# کارشناس: 316
# صندوق: 311
# شرکت‌های: 310
# مردم: 309
# شورای: 309
# حذف: 309
# خدمات: 300
# بررسی: 297
# واحدی: 295
# نیرو: 290
# ثبت: 289
# جمله: 289
# پیش‌بینی: 288
# دوشنبه: 288
# طریق: 286
# داخلی: 283
# ارزی: 283
# آمار: 283
# ارائه: 280
# فولاد: 280
# خصوصی: 280
# دریافت: 279
# سوخت: 277
# دلیل: 277
# حمل: 276
# تأمین: 272
# دفتر: 270
# ابتدای: 269
# سهام: 268
# کمیسیون: 268
# شرایط: 266
# اصناف: 264
# بازرگانی: 260
# اسلامی: 259
# مشابه: 259
# رئیس‌کل: 255
# تورم: 253
# نفتی: 252
# تجاری: 251
# کشورهای: 250
# سطح: 250
# نفر: 249
# اوپک: 246
# چهارشنبه: 244
# عامل: 242
# جهانی: 239
# خارجی: 239
# صرافی‌های: 237
# حمایت: 237
# ۱۰۰: 236
# سرپرست: 235
# برگزار: 234
# اجرایی: 233
# رئیس‌جمهور: 233
# مشترک: 233
# هواپیمایی: 232
# اطلاعات: 230
# صدور: 229
# نظام: 229
# ثابت: 228

# %%
predicted_labels = X_test_clean.apply(classifier.predict)
# Out:
# Streaming output truncated to the last 5000 lines.
# Scores per class: defaultdict(<class 'float'>, {'Tech': -141.939949145824, 'Sport': -79.1091349513306, 'Economy': -145.3396484396404})
# Predicted class: Sport
# Scores per class: defaultdict(<class 'float'>, {'Tech': -83.94527791105122, 'Sport': -118.84034432558228, 'Economy': -98.54121491661962})
# Predicted class: Tech
# Scores per class: defaultdict(<class 'float'>, {'Tech': -192.84041944614447, 'Sport': -224.24089393082423, 'Economy': -172.19651616006985})
# Predicted class: Economy
# Scores per class: defaultdict(<class 'float'>, {'Tech': -148.28005714593542, 'Sport': -119.86432150379417, 'Economy': -154.33250440464934})
# Predicted class: Sport
# Scores per class: defaultdict(<class 'float'>, {'Tech': -128.141410333565, 'Sport': -90.44361317632561, 'Economy': -120.09006472812088})
# Predicted class: Sport
# Scores per class: defaultdict(<class 'float'>, {'Tech': -208.15522346237853, 'Sport': -184.6144866584607, 'Economy': -199.4647653004867})
# Predicted class: Sport
# Scores per class: defaultdict(<class 'float'>, {'Tech': -140.47675515302117, 'Sport': -194.12580692033734, 'Economy': -169.9030330908935})
# Predicted class: Tech
# Scores per class: defaultdict(<class 'float'>, {'Tech': -87.99887876330249, 'Sport': -125.90246195282168, 'Economy': -115.79808809566694})
# Predicted class: Tech
# Scores per class: defaultdict(<class 'float'>, {'Tech': -147.2227217213612, 'Sport': -148.11307753149265, 'Economy': -110.28052280472723})
# Predicted class: Economy
# Scores per class: defaultdict(<class 'float'>, {'Tech': -74.87975051875662, 'Sport': -45.89816397646201, 'Economy': -77.86097363083076})
# Predicted class: Sport
# Scores per class: defaultdict(<class 'float'>, {'Tech': -115.95349675469433, 'Sport': -162.05229171265321, 'Economy': -132.3772807302858})
# Predicted class: Tech
# Scores per class: defaultdict(<class 'float'>, {'Tech': -148.88592895355856, 'Sport': -104.89994952777558, 'Economy': -147.48381759672475})
# Predicted class: Sport
# Scores per class: defaultdict(<class 'float'>, {'Tech': -103.47814319722066, 'Sport': -120.48589358988572, 'Economy': -91.72306584516899})
# Predicted class: Economy
# Scores per class: defaultdict(<class 'float'>, {'Tech': -111.47869147327631, 'Sport': -74.91296090173925, 'Economy': -123.83773675829407})
# Predicted class: Sport
# Scores per class: defaultdict(<class 'float'>, {'Tech': -105.07462437983958, 'Sport': -120.72488711057022, 'Economy': -83.88484967772756})
# Predicted class: Economy
# Scores per class: defaultdict(<class 'float'>, {'Tech': -87.68888545855806, 'Sport': -64.74379316253955, 'Economy': -90.4891239919467})
# Predicted class: Sport
# Scores per class: defaultdict(<class 'float'>, {'Tech': -198.39015396422832, 'Sport': -116.92939367059009, 'Economy': -205.6493634494838})
# Predicted class: Sport
# Scores per class: defaultdict(<class 'float'>, {'Tech': -174.28353238105504, 'Sport': -207.72458580591862, 'Economy': -178.06212642174492})
# Predicted class: Tech
# Scores per class: defaultdict(<class 'float'>, {'Tech': -124.40901085662081, 'Sport': -136.47874141588682, 'Economy': -89.90503959145376})
# Predicted class: Economy
# Scores per class: defaultdict(<class 'float'>, {'Tech': -55.21956329383087, 'Sport': -78.00872393330228, 'Economy': -76.23475979692267})
# Predicted class: Tech
# Scores per class: defaultdict(<class 'float'>, {'Tech': -166.50070988013633, 'Sport': -221.9149813092097, 'Economy': -215.97018543634567})
# Predicted class: Tech
# Scores per class: defaultdict(<class 'float'>, {'Tech': -103.3371365574314, 'Sport': -121.36699777070575, 'Economy': -75.14886928452624})
# Predicted class: Economy
# Scores per class: defaultdict(<class 'float'>, {'Tech': -101.61658846556352, 'Sport': -67.5651294999154, 'Economy': -101.49088134930723})
# Predicted class: Sport
# Scores per class: defaultdict(<class 'float'>, {'Tech': -109.89186539078872, 'Sport': -141.69431661018325, 'Economy': -131.28491509525097})
# Predicted class: Tech
# Scores per class: defaultdict(<class 'float'>, {'Tech': -118.62496466509364, 'Sport': -91.61887004635786, 'Economy': -122.92066732580821})
# Predicted class: Sport
# Scores per class: defaultdict(<class 'float'>, {'Tech': -106.6413355829938, 'Sport': -109.87392894812515, 'Economy': -92.21370227861887})
# Predicted class: Economy
# Scores per class: defaultdict(<class 'float'>, {'Tech': -128.5189777046211, 'Sport': -86.2791333308832, 'Economy': -133.12712556331863})
# Predicted class: Sport
# Scores per class: defaultdict(<class 'float'>, {'Tech': -168.08035033516515, 'Sport': -115.72141740327882, 'Economy': -178.8447306805099})
# Predicted class: Sport
# Scores per class: defaultdict(<class 'float'>, {'Tech': -69.500563383339, 'Sport': -99.6490184092512, 'Economy': -88.52966524390159})
# Predicted class: Tech
# Scores per class: defaultdict(<class 'float'>, {'Tech': -181.32173187434304, 'Sport': -156.58835506259814, 'Economy': -182.58790054216686})
# Predicted class: Sport
# Scores per class: defaultdict(<class 'float'>, {'Tech': -245.92532344177943, 'Sport': -245.92489839098246, 'Economy': -201.1797379036412})
# Predicted class: Economy
# Scores per class: defaultdict(<class 'float'>, {'Tech': -146.02445632985743, 'Sport': -96.57889229198798, 'Economy': -155.0026167223551})
# Predicted class: Sport
# Scores per class: defaultdict(<class 'float'>, {'Tech': -101.17088145349452, 'Sport': -121.62563734534015, 'Economy': -95.75424660902614})
# Predicted class: Economy
# Scores per class: defaultdict(<class 'float'>, {'Tech': -136.07333039490442, 'Sport': -132.36002339801783, 'Economy': -121.56103910498177})
# Predicted class: Economy
# Scores per class: defaultdict(<class 'float'>, {'Tech': -119.85420486707766, 'Sport': -168.3577652198351, 'Economy': -137.68467477653823})
# Predicted class: Tech
# Scores per class: defaultdict(<class 'float'>, {'Tech': -110.5409057609149, 'Sport': -153.00507197976268, 'Economy': -107.44372449387858})
# Predicted class: Economy
# Scores per class: defaultdict(<class 'float'>, {'Tech': -174.5277575654484, 'Sport': -193.52243833154006, 'Economy': -137.21722330269932})
# Predicted class: Economy
# Scores per class: defaultdict(<class 'float'>, {'Tech': -149.4165743629432, 'Sport': -95.74422516155524, 'Economy': -148.0547948842415})
# Predicted class: Sport
# Scores per class: defaultdict(<class 'float'>, {'Tech': -155.89627057169108, 'Sport': -211.64464851734908, 'Economy': -205.60330733089572})
# Predicted class: Tech
# Scores per class: defaultdict(<class 'float'>, {'Tech': -145.84979829260786, 'Sport': -136.55866779337984, 'Economy': -150.57511318624182})
# Predicted class: Sport
# Scores per class: defaultdict(<class 'float'>, {'Tech': -100.7453185656673, 'Sport': -75.7945087438155, 'Economy': -107.683220748763})
# Predicted class: Sport
# Scores per class: defaultdict(<class 'float'>, {'Tech': -189.14947267131916, 'Sport': -219.183906687166, 'Economy': -139.5018606724565})
# Predicted class: Economy
# Scores per class: defaultdict(<class 'float'>, {'Tech': -108.29403077922905, 'Sport': -163.39734542492224, 'Economy': -117.09804026442545})
# Predicted class: Tech
# Scores per class: defaultdict(<class 'float'>, {'Tech': -67.45637726085995, 'Sport': -87.54447013067754, 'Economy': -65.70620178276249})
# Predicted class: Economy
# Scores per class: defaultdict(<class 'float'>, {'Tech': -129.02205351892565, 'Sport': -81.29126688458638, 'Economy': -120.81689548873686})
# Predicted class: Sport
# Scores per class: defaultdict(<class 'float'>, {'Tech': -142.984831362297, 'Sport': -84.08821899406621, 'Economy': -147.8245982060337})
# Predicted class: Sport
# Scores per class: defaultdict(<class 'float'>, {'Tech': -143.10786509179144, 'Sport': -195.96960268667755, 'Economy': -173.46643689577402})
# Predicted class: Tech
# Scores per class: defaultdict(<class 'float'>, {'Tech': -139.94508497080662, 'Sport': -177.86947819757867, 'Economy': -152.565230203238})
# Predicted class: Tech
# Scores per class: defaultdict(<class 'float'>, {'Tech': -148.1211030600967, 'Sport': -142.8181478017129, 'Economy': -150.02883931231068})
# Predicted class: Sport
# Scores per class: defaultdict(<class 'float'>, {'Tech': -138.92584940606852, 'Sport': -167.77444397003222, 'Economy': -127.98981478206574})
# Predicted class: Economy
# Scores per class: defaultdict(<class 'float'>, {'Tech': -199.66987829554364, 'Sport': -239.937041843977, 'Economy': -164.1199276007941})
# Predicted class: Economy
# Scores per class: defaultdict(<class 'float'>, {'Tech': -133.27921934433306, 'Sport': -190.30059584442637, 'Economy': -172.21821996727164})
# Predicted class: Tech
# Scores per class: defaultdict(<class 'float'>, {'Tech': -145.11276729093115, 'Sport': -185.45810658857363, 'Economy': -186.02743277026138})
# Predicted class: Tech
# Scores per class: defaultdict(<class 'float'>, {'Tech': -79.13910316270277, 'Sport': -124.39496250144978, 'Economy': -102.09266827530173})
# Predicted class: Tech
# Scores per class: defaultdict(<class 'float'>, {'Tech': -163.9097913630317, 'Sport': -202.13774839909334, 'Economy': -159.1996651052907})
# Predicted class: Economy
# Scores per class: defaultdict(<class 'float'>, {'Tech': -121.96449832691403, 'Sport': -168.7107340624972, 'Economy': -166.71387069478632})
# Predicted class: Tech
# Scores per class: defaultdict(<class 'float'>, {'Tech': -140.12551774308554, 'Sport': -171.70423638864577, 'Economy': -120.06404764757886})
# Predicted class: Economy
# Scores per class: defaultdict(<class 'float'>, {'Tech': -126.0375647992492, 'Sport': -166.91928462054446, 'Economy': -111.19425704440809})
# Predicted class: Economy
# Scores per class: defaultdict(<class 'float'>, {'Tech': -116.98959329438073, 'Sport': -79.20049119201529, 'Economy': -131.232264960718})
# Predicted class: Sport
# Scores per class: defaultdict(<class 'float'>, {'Tech': -110.97826289051123, 'Sport': -159.03464075208717, 'Economy': -129.47037820016604})
# Predicted class: Tech
# Scores per class: defaultdict(<class 'float'>, {'Tech': -177.12503542139874, 'Sport': -118.81946700494565, 'Economy': -177.3842847507509})
# Predicted class: Sport
# Scores per class: defaultdict(<class 'float'>, {'Tech': -128.12761450056075, 'Sport': -107.72032260276461, 'Economy': -131.5624118522016})
# Predicted class: Sport
# Scores per class: defaultdict(<class 'float'>, {'Tech': -101.61658846556352, 'Sport': -67.5651294999154, 'Economy': -101.49088134930723})
# Predicted class: Sport
# Scores per class: defaultdict(<class 'float'>, {'Tech': -164.5643261048963, 'Sport': -99.23769587293512, 'Economy': -157.63742190262423})
# Predicted class: Sport
# Scores per class: defaultdict(<class 'float'>, {'Tech': -143.83677306117397, 'Sport': -199.37082293469612, 'Economy': -168.74477280232233})
# Predicted class: Tech
# Scores per class: defaultdict(<class 'float'>, {'Tech': -136.3016190140492, 'Sport': -188.39254031814906, 'Economy': -149.56893041604687})
# Predicted class: Tech
# Scores per class: defaultdict(<class 'float'>, {'Tech': -155.82581048716136, 'Sport': -180.03271022844015, 'Economy': -110.32115861727287})
# Predicted class: Economy
# Scores per class: defaultdict(<class 'float'>, {'Tech': -175.55773151547965, 'Sport': -192.75104472291517, 'Economy': -154.47658407064284})
# Predicted class: Economy
# Scores per class: defaultdict(<class 'float'>, {'Tech': -99.90346932419175, 'Sport': -123.25079305338589, 'Economy': -110.2414263542129})
# Predicted class: Tech
# Scores per class: defaultdict(<class 'float'>, {'Tech': -183.22959824612778, 'Sport': -196.81032634759487, 'Economy': -156.62186323434003})
# Predicted class: Economy
# Scores per class: defaultdict(<class 'float'>, {'Tech': -139.88834207562698, 'Sport': -173.66278480121815, 'Economy': -162.47357580991277})
# Predicted class: Tech
# Scores per class: defaultdict(<class 'float'>, {'Tech': -189.5064549227601, 'Sport': -142.77549783919045, 'Economy': -171.92628271911772})
# Predicted class: Sport
# Scores per class: defaultdict(<class 'float'>, {'Tech': -162.2797604246928, 'Sport': -231.22282237488793, 'Economy': -203.86384220040503})
# Predicted class: Tech
# Scores per class: defaultdict(<class 'float'>, {'Tech': -109.36080258011137, 'Sport': -76.48912724895852, 'Economy': -112.06207242118528})
# Predicted class: Sport
# Scores per class: defaultdict(<class 'float'>, {'Tech': -129.45230027704866, 'Sport': -102.3955739299909, 'Economy': -130.06697279296137})
# Predicted class: Sport
# Scores per class: defaultdict(<class 'float'>, {'Tech': -107.09833473321596, 'Sport': -161.94806754553412, 'Economy': -134.74296085599016})
# Predicted class: Tech
# Scores per class: defaultdict(<class 'float'>, {'Tech': -223.36234295663604, 'Sport': -127.9769906940255, 'Economy': -229.15493914309693})
# Predicted class: Sport
# Scores per class: defaultdict(<class 'float'>, {'Tech': -132.98909554751052, 'Sport': -167.7275504012452, 'Economy': -113.58357294175482})
# Predicted class: Economy
# Scores per class: defaultdict(<class 'float'>, {'Tech': -127.86191886942528, 'Sport': -181.8860369825176, 'Economy': -136.29196663548774})
# Predicted class: Tech
# Scores per class: defaultdict(<class 'float'>, {'Tech': -155.35038861371822, 'Sport': -101.76782606879517, 'Economy': -166.03057200569722})
# Predicted class: Sport
# Scores per class: defaultdict(<class 'float'>, {'Tech': -175.95419301323588, 'Sport': -225.47342536435988, 'Economy': -186.9020536687842})
# Predicted class: Tech
# Scores per class: defaultdict(<class 'float'>, {'Tech': -103.47842543873365, 'Sport': -61.775299466340655, 'Economy': -105.07981166250876})
# Predicted class: Sport
# Scores per class: defaultdict(<class 'float'>, {'Tech': -115.60152031869556, 'Sport': -159.5959349824065, 'Economy': -135.69971702612114})
# Predicted class: Tech
# Scores per class: defaultdict(<class 'float'>, {'Tech': -157.41650819958735, 'Sport': -186.4616692647739, 'Economy': -136.93594954276622})
# Predicted class: Economy
# Scores per class: defaultdict(<class 'float'>, {'Tech': -95.41821338722445, 'Sport': -132.75386311387143, 'Economy': -119.4832039082952})
# Predicted class: Tech
# Scores per class: defaultdict(<class 'float'>, {'Tech': -88.56748093697598, 'Sport': -54.07577846189666, 'Economy': -90.6432213484286})
# Predicted class: Sport
# Scores per class: defaultdict(<class 'float'>, {'Tech': -152.49415409476018, 'Sport': -219.16575470102453, 'Economy': -165.1420382762084})
# Predicted class: Tech
# Scores per class: defaultdict(<class 'float'>, {'Tech': -223.36234295663604, 'Sport': -127.9769906940255, 'Economy': -229.15493914309693})
# Predicted class: Sport
# Scores per class: defaultdict(<class 'float'>, {'Tech': -215.82843351769358, 'Sport': -133.97776415229188, 'Economy': -222.78338421505384})
# Predicted class: Sport
# Scores per class: defaultdict(<class 'float'>, {'Tech': -161.9693279362479, 'Sport': -106.79601863688805, 'Economy': -160.7713441170599})
# Predicted class: Sport
# Scores per class: defaultdict(<class 'float'>, {'Tech': -121.96449832691403, 'Sport': -168.7107340624972, 'Economy': -166.71387069478632})
# Predicted class: Tech
# Scores per class: defaultdict(<class 'float'>, {'Tech': -182.5801632087142, 'Sport': -248.09854907363024, 'Economy': -225.54081422914618})
# Predicted class: Tech
# Scores per class: defaultdict(<class 'float'>, {'Tech': -89.50192665539439, 'Sport': -110.57531569002822, 'Economy': -105.32614257585291})
# Predicted class: Tech
# Scores per class: defaultdict(<class 'float'>, {'Tech': -146.41327602530578, 'Sport': -86.40139487582314, 'Economy': -141.97274323017106})
# Predicted class: Sport
# Scores per class: defaultdict(<class 'float'>, {'Tech': -78.61888075029547, 'Sport': -81.9022807510044, 'Economy': -57.47124005187363})
# Predicted class: Economy
# Scores per class: defaultdict(<class 'float'>, {'Tech': -105.5908081442798, 'Sport': -57.47329782345416, 'Economy': -113.61214909014818})
# Predicted class: Sport
# Scores per class: defaultdict(<class 'float'>, {'Tech': -155.3045754896096, 'Sport': -170.9727685585849, 'Economy': -123.58715837289759})
# Predicted class: Economy
# Scores per class: defaultdict(<class 'float'>, {'Tech': -242.39161507730384, 'Sport': -155.4663954936093, 'Economy': -241.319424868079})
# Predicted class: Sport
# Scores per class: defaultdict(<class 'float'>, {'Tech': -67.45637726085995, 'Sport': -87.54447013067754, 'Economy': -65.70620178276249})
# Predicted class: Economy
# Scores per class: defaultdict(<class 'float'>, {'Tech': -176.91306228341338, 'Sport': -179.5607956980421, 'Economy': -133.61921642134828})
# Predicted class: Economy
# Scores per class: defaultdict(<class 'float'>, {'Tech': -177.99161891189672, 'Sport': -186.77823234221967, 'Economy': -141.10412150028804})
# Predicted class: Economy
# Scores per class: defaultdict(<class 'float'>, {'Tech': -213.5616219154731, 'Sport': -139.704272589946, 'Economy': -207.96918530303418})
# Predicted class: Sport
# Scores per class: defaultdict(<class 'float'>, {'Tech': -152.8939557484153, 'Sport': -157.80778749905735, 'Economy': -126.25219383369682})
# Predicted class: Economy
# Scores per class: defaultdict(<class 'float'>, {'Tech': -168.08035033516515, 'Sport': -115.72141740327882, 'Economy': -178.8447306805099})
# Predicted class: Sport
# Scores per class: defaultdict(<class 'float'>, {'Tech': -145.86062842773606, 'Sport': -167.67594330801722, 'Economy': -130.35386075839529})
# Predicted class: Economy
# Scores per class: defaultdict(<class 'float'>, {'Tech': -110.8925214394393, 'Sport': -124.34280958456984, 'Economy': -101.23038324833925})
# Predicted class: Economy
# Scores per class: defaultdict(<class 'float'>, {'Tech': -85.78509690581963, 'Sport': -104.69806990136101, 'Economy': -111.22421759108629})
# Predicted class: Tech
# Scores per class: defaultdict(<class 'float'>, {'Tech': -154.26649528566472, 'Sport': -90.60053536446371, 'Economy': -149.01353784854945})
# Predicted class: Sport
# Scores per class: defaultdict(<class 'float'>, {'Tech': -108.29403077922905, 'Sport': -163.39734542492224, 'Economy': -117.09804026442545})
# Predicted class: Tech
# Scores per class: defaultdict(<class 'float'>, {'Tech': -136.64829377348286, 'Sport': -203.1896756175183, 'Economy': -183.72038832227037})
# Predicted class: Tech
# Scores per class: defaultdict(<class 'float'>, {'Tech': -112.67646666235592, 'Sport': -160.36009641372115, 'Economy': -149.19712047473624})
# Predicted class: Tech
# Scores per class: defaultdict(<class 'float'>, {'Tech': -129.48434359552377, 'Sport': -91.80498318278757, 'Economy': -135.12341696803747})
# Predicted class: Sport
# Scores per class: defaultdict(<class 'float'>, {'Tech': -133.08504559696502, 'Sport': -166.55853880843, 'Economy': -145.22282198925382})
# Predicted class: Tech
# Scores per class: defaultdict(<class 'float'>, {'Tech': -99.61621281605632, 'Sport': -108.15635094299091, 'Economy': -80.20320808316156})
# Predicted class: Economy
# Scores per class: defaultdict(<class 'float'>, {'Tech': -117.33423877204946, 'Sport': -162.4844590163341, 'Economy': -120.12066132347042})
# Predicted class: Tech
# Scores per class: defaultdict(<class 'float'>, {'Tech': -124.46609686652302, 'Sport': -78.34001322620163, 'Economy': -131.9928361498775})
# Predicted class: Sport
# Scores per class: defaultdict(<class 'float'>, {'Tech': -242.39161507730384, 'Sport': -155.4663954936093, 'Economy': -241.319424868079})
# Predicted class: Sport
# Scores per class: defaultdict(<class 'float'>, {'Tech': -132.10157653832414, 'Sport': -150.7748980073827, 'Economy': -93.01420773932495})
# Predicted class: Economy
# Scores per class: defaultdict(<class 'float'>, {'Tech': -148.65267999071546, 'Sport': -222.78719897292166, 'Economy': -185.55448506614601})
# Predicted class: Tech
# Scores per class: defaultdict(<class 'float'>, {'Tech': -95.31046545736234, 'Sport': -129.43581413882595, 'Economy': -100.61230208710775})
# Predicted class: Tech
# Scores per class: defaultdict(<class 'float'>, {'Tech': -158.5749377737217, 'Sport': -234.40405460902136, 'Economy': -181.83747823819223})
# Predicted class: Tech
# Scores per class: defaultdict(<class 'float'>, {'Tech': -201.67167850379863, 'Sport': -217.03499511042844, 'Economy': -160.63272235608127})
# Predicted class: Economy
# Scores per class: defaultdict(<class 'float'>, {'Tech': -143.2219141955816, 'Sport': -180.7538975306241, 'Economy': -123.02784976360795})
# Predicted class: Economy
# Scores per class: defaultdict(<class 'float'>, {'Tech': -158.8739284529519, 'Sport': -95.99326955265515, 'Economy': -162.3956522889447})
# Predicted class: Sport
# Scores per class: defaultdict(<class 'float'>, {'Tech': -101.89479329117361, 'Sport': -68.64000405489912, 'Economy': -99.70757670244353})
# Predicted class: Sport
# Scores per class: defaultdict(<class 'float'>, {'Tech': -111.55784901965502, 'Sport': -150.33891709513395, 'Economy': -112.79154641916185})
# Predicted class: Tech
# Scores per class: defaultdict(<class 'float'>, {'Tech': -77.41159178376324, 'Sport': -46.97967491333249, 'Economy': -84.2877116003597})
# Predicted class: Sport
# Scores per class: defaultdict(<class 'float'>, {'Tech': -112.8625395798228, 'Sport': -153.02225294401205, 'Economy': -133.1429733112281})
# Predicted class: Tech
# Scores per class: defaultdict(<class 'float'>, {'Tech': -148.61623833291776, 'Sport': -208.24080353056434, 'Economy': -191.92501870392965})
# Predicted class: Tech
# Scores per class: defaultdict(<class 'float'>, {'Tech': -164.99874979087681, 'Sport': -236.1998445413394, 'Economy': -185.52439781485174})
# Predicted class: Tech
# Scores per class: defaultdict(<class 'float'>, {'Tech': -183.58186836070755, 'Sport': -220.36991836987255, 'Economy': -140.284734012691})
# Predicted class: Economy
# Scores per class: defaultdict(<class 'float'>, {'Tech': -146.02445632985743, 'Sport': -96.57889229198798, 'Economy': -155.0026167223551})
# Predicted class: Sport
# Scores per class: defaultdict(<class 'float'>, {'Tech': -124.68654548003907, 'Sport': -79.13404105554285, 'Economy': -124.62551538731152})
# Predicted class: Sport
# Scores per class: defaultdict(<class 'float'>, {'Tech': -153.79405605668566, 'Sport': -192.82053558495323, 'Economy': -206.10904864511582})
# Predicted class: Tech
# Scores per class: defaultdict(<class 'float'>, {'Tech': -102.63074283140588, 'Sport': -65.85947294963441, 'Economy': -108.15034206460994})
# Predicted class: Sport
# Scores per class: defaultdict(<class 'float'>, {'Tech': -170.57186548058357, 'Sport': -196.89616904345408, 'Economy': -146.66632651644173})
# Predicted class: Economy
# Scores per class: defaultdict(<class 'float'>, {'Tech': -97.60839258584352, 'Sport': -60.09612963344108, 'Economy': -103.06504061103469})
# Predicted class: Sport
# Scores per class: defaultdict(<class 'float'>, {'Tech': -215.64633043412746, 'Sport': -229.017137239816, 'Economy': -177.66804125194713})
# Predicted class: Economy
# Scores per class: defaultdict(<class 'float'>, {'Tech': -112.45316760149359, 'Sport': -77.30658405452948, 'Economy': -116.25239363766833})
# Predicted class: Sport
# Scores per class: defaultdict(<class 'float'>, {'Tech': -124.65868306801441, 'Sport': -104.2769362360869, 'Economy': -117.56302638967517})
# Predicted class: Sport
# Scores per class: defaultdict(<class 'float'>, {'Tech': -127.50429814921804, 'Sport': -83.40514454987022, 'Economy': -133.20269420972323})
# Predicted class: Sport
# Scores per class: defaultdict(<class 'float'>, {'Tech': -119.73484940862804, 'Sport': -138.61410633175709, 'Economy': -87.37817162922899})
# Predicted class: Economy
# Scores per class: defaultdict(<class 'float'>, {'Tech': -100.69409285183609, 'Sport': -64.71798162281013, 'Economy': -105.17077156158153})
# Predicted class: Sport
# Scores per class: defaultdict(<class 'float'>, {'Tech': -104.851437191524, 'Sport': -127.09095365872682, 'Economy': -84.58199338161562})
# Predicted class: Economy
# Scores per class: defaultdict(<class 'float'>, {'Tech': -109.3695409592361, 'Sport': -80.89958288437197, 'Economy': -116.10998123325543})
# Predicted class: Sport
# Scores per class: defaultdict(<class 'float'>, {'Tech': -78.61999350841177, 'Sport': -99.13538878808568, 'Economy': -59.36758154213236})
# Predicted class: Economy
# Scores per class: defaultdict(<class 'float'>, {'Tech': -54.07124587298085, 'Sport': -37.61147427418536, 'Economy': -54.15697713004097})
# Predicted class: Sport
# Scores per class: defaultdict(<class 'float'>, {'Tech': -188.96034355604286, 'Sport': -218.0869448240487, 'Economy': -134.3888611848239})
# Predicted class: Economy
# Scores per class: defaultdict(<class 'float'>, {'Tech': -112.68262794040561, 'Sport': -69.52188282057918, 'Economy': -119.63594060367173})
# Predicted class: Sport
# Scores per class: defaultdict(<class 'float'>, {'Tech': -124.47179408359865, 'Sport': -171.9150663973592, 'Economy': -154.66105456947327})
# Predicted class: Tech
# Scores per class: defaultdict(<class 'float'>, {'Tech': -70.23589401973015, 'Sport': -119.15351152489175, 'Economy': -93.87194169649867})
# Predicted class: Tech
# Scores per class: defaultdict(<class 'float'>, {'Tech': -129.1519647451991, 'Sport': -81.57627162852795, 'Economy': -133.1171496848569})
# Predicted class: Sport
# Scores per class: defaultdict(<class 'float'>, {'Tech': -83.39584864030556, 'Sport': -102.04978724724528, 'Economy': -99.1778848291264})
# Predicted class: Tech
# Scores per class: defaultdict(<class 'float'>, {'Tech': -131.2786786975375, 'Sport': -150.0082745730208, 'Economy': -105.27973517428359})
# Predicted class: Economy
# Scores per class: defaultdict(<class 'float'>, {'Tech': -148.23092657615965, 'Sport': -152.61834017239687, 'Economy': -122.2567307081123})
# Predicted class: Economy
# Scores per class: defaultdict(<class 'float'>, {'Tech': -123.13001874348188, 'Sport': -134.51657259270323, 'Economy': -92.56982083910832})
# Predicted class: Economy
# Scores per class: defaultdict(<class 'float'>, {'Tech': -125.55534992710562, 'Sport': -141.07717520644064, 'Economy': -116.29838190440667})
# Predicted class: Economy
# Scores per class: defaultdict(<class 'float'>, {'Tech': -131.60674652503704, 'Sport': -75.73161612635684, 'Economy': -130.45671386883512})
# Predicted class: Sport
# Scores per class: defaultdict(<class 'float'>, {'Tech': -101.37176909891961, 'Sport': -59.13389207138995, 'Economy': -104.40702276196548})
# Predicted class: Sport
# Scores per class: defaultdict(<class 'float'>, {'Tech': -147.15837171463707, 'Sport': -106.76470117136192, 'Economy': -144.12841366128788})
# Predicted class: Sport
# Scores per class: defaultdict(<class 'float'>, {'Tech': -126.85040190095151, 'Sport': -131.16342309397018, 'Economy': -102.48152811142434})
# Predicted class: Economy
# Scores per class: defaultdict(<class 'float'>, {'Tech': -146.63532786809037, 'Sport': -216.53408991470823, 'Economy': -188.6861581931691})
# Predicted class: Tech
# Scores per class: defaultdict(<class 'float'>, {'Tech': -91.46961241176446, 'Sport': -141.13302597644042, 'Economy': -130.28193678008427})
# Predicted class: Tech
# Scores per class: defaultdict(<class 'float'>, {'Tech': -214.74066217981513, 'Sport': -216.34550748166274, 'Economy': -174.36042429588613})
# Predicted class: Economy
# Scores per class: defaultdict(<class 'float'>, {'Tech': -116.54154659609476, 'Sport': -160.73634848022078, 'Economy': -125.46246640633917})
# Predicted class: Tech
# Scores per class: defaultdict(<class 'float'>, {'Tech': -142.78226167371935, 'Sport': -163.0514712456026, 'Economy': -125.32644463348856})
# Predicted class: Economy
# Scores per class: defaultdict(<class 'float'>, {'Tech': -158.8739284529519, 'Sport': -95.99326955265515, 'Economy': -162.3956522889447})
# Predicted class: Sport
# Scores per class: defaultdict(<class 'float'>, {'Tech': -110.47264895130851, 'Sport': -118.00330032641686, 'Economy': -97.74285559149405})
# Predicted class: Economy
# Scores per class: defaultdict(<class 'float'>, {'Tech': -162.52186279907335, 'Sport': -188.60505896583675, 'Economy': -137.69911112533634})
# Predicted class: Economy
# Scores per class: defaultdict(<class 'float'>, {'Tech': -144.8233973792404, 'Sport': -163.38135399314652, 'Economy': -158.51386749717707})
# Predicted class: Tech
# Scores per class: defaultdict(<class 'float'>, {'Tech': -147.17586322816112, 'Sport': -166.98739671459174, 'Economy': -119.32366419949834})
# Predicted class: Economy
# Scores per class: defaultdict(<class 'float'>, {'Tech': -196.8480772432411, 'Sport': -129.82274609672208, 'Economy': -202.4406404299633})
# Predicted class: Sport
# Scores per class: defaultdict(<class 'float'>, {'Tech': -129.31352113886422, 'Sport': -187.53526137929765, 'Economy': -167.8057398312572})
# Predicted class: Tech
# Scores per class: defaultdict(<class 'float'>, {'Tech': -202.41901717141133, 'Sport': -148.3617317984136, 'Economy': -197.368954383613})
# Predicted class: Sport
# Scores per class: defaultdict(<class 'float'>, {'Tech': -130.18503660639402, 'Sport': -165.63252818468337, 'Economy': -166.88101676610043})
# Predicted class: Tech
# Scores per class: defaultdict(<class 'float'>, {'Tech': -83.60851474974642, 'Sport': -127.50888413770268, 'Economy': -97.77520484441574})
# Predicted class: Tech
# Scores per class: defaultdict(<class 'float'>, {'Tech': -150.1463620339882, 'Sport': -155.2790482232606, 'Economy': -128.0181436197298})
# Predicted class: Economy
# Scores per class: defaultdict(<class 'float'>, {'Tech': -117.9191517161345, 'Sport': -75.43590800490152, 'Economy': -124.57462706787683})
# Predicted class: Sport
# Scores per class: defaultdict(<class 'float'>, {'Tech': -150.49947922027025, 'Sport': -175.68913224660344, 'Economy': -125.73541889253836})
# Predicted class: Economy
# Scores per class: defaultdict(<class 'float'>, {'Tech': -144.3736314614947, 'Sport': -214.0134840475672, 'Economy': -164.92114818854802})
# Predicted class: Tech
# Scores per class: defaultdict(<class 'float'>, {'Tech': -145.15504390394995, 'Sport': -87.91845733445209, 'Economy': -148.49233206642344})
# Predicted class: Sport
# Scores per class: defaultdict(<class 'float'>, {'Tech': -188.64244920790756, 'Sport': -213.92019697976758, 'Economy': -167.16650623851405})
# Predicted class: Economy
# Scores per class: defaultdict(<class 'float'>, {'Tech': -62.40554442708697, 'Sport': -65.23840195249613, 'Economy': -51.736347805948064})
# Predicted class: Economy
# Scores per class: defaultdict(<class 'float'>, {'Tech': -99.90361804347815, 'Sport': -133.94582701297955, 'Economy': -140.5930238238167})
# Predicted class: Tech
# Scores per class: defaultdict(<class 'float'>, {'Tech': -139.88834207562698, 'Sport': -173.66278480121815, 'Economy': -162.47357580991277})
# Predicted class: Tech
# Scores per class: defaultdict(<class 'float'>, {'Tech': -85.85808024805583, 'Sport': -42.98722950456107, 'Economy': -83.06107020509546})
# Predicted class: Sport
# Scores per class: defaultdict(<class 'float'>, {'Tech': -88.56748093697598, 'Sport': -54.07577846189666, 'Economy': -90.6432213484286})
# Predicted class: Sport
# Scores per class: defaultdict(<class 'float'>, {'Tech': -103.00971987709885, 'Sport': -142.86252093666923, 'Economy': -109.18264457326246})
# Predicted class: Tech
# Scores per class: defaultdict(<class 'float'>, {'Tech': -129.87763933960926, 'Sport': -128.59916987595184, 'Economy': -109.53664249616787})
# Predicted class: Economy
# Scores per class: defaultdict(<class 'float'>, {'Tech': -111.26241727436818, 'Sport': -91.12420290934546, 'Economy': -104.10435758472686})
# Predicted class: Sport
# Scores per class: defaultdict(<class 'float'>, {'Tech': -166.25226314613775, 'Sport': -185.55832849338205, 'Economy': -128.1482859580837})
# Predicted class: Economy
# Scores per class: defaultdict(<class 'float'>, {'Tech': -157.2591699369195, 'Sport': -186.65136700181725, 'Economy': -137.08330690100567})
# Predicted class: Economy
# Scores per class: defaultdict(<class 'float'>, {'Tech': -156.84121959071453, 'Sport': -208.52618109870258, 'Economy': -182.0333601823983})
# Predicted class: Tech
# Scores per class: defaultdict(<class 'float'>, {'Tech': -104.06854418146354, 'Sport': -66.89702802925422, 'Economy': -108.72828169573893})
# Predicted class: Sport
# Scores per class: defaultdict(<class 'float'>, {'Tech': -137.59319711014896, 'Sport': -141.9151876706826, 'Economy': -111.55414597111674})
# Predicted class: Economy
# Scores per class: defaultdict(<class 'float'>, {'Tech': -108.42967026217075, 'Sport': -160.71524166903467, 'Economy': -130.42144510889335})
# Predicted class: Tech
# Scores per class: defaultdict(<class 'float'>, {'Tech': -173.15021153752355, 'Sport': -229.77975632945572, 'Economy': -216.7381444415611})
# Predicted class: Tech
# Scores per class: defaultdict(<class 'float'>, {'Tech': -193.74248865852977, 'Sport': -223.0510816974986, 'Economy': -171.7348162872364})
# Predicted class: Economy
# Scores per class: defaultdict(<class 'float'>, {'Tech': -135.71086140095952, 'Sport': -88.71267912770239, 'Economy': -144.96825910749487})
# Predicted class: Sport
# Scores per class: defaultdict(<class 'float'>, {'Tech': -176.42774087671398, 'Sport': -195.8631400982357, 'Economy': -144.15980280485664})
# Predicted class: Economy
# Scores per class: defaultdict(<class 'float'>, {'Tech': -95.6709565762153, 'Sport': -149.64267955854663, 'Economy': -140.98308357142378})
# Predicted class: Tech
# Scores per class: defaultdict(<class 'float'>, {'Tech': -87.55274110718139, 'Sport': -120.69520889166309, 'Economy': -112.97078406476876})
# Predicted class: Tech
# Scores per class: defaultdict(<class 'float'>, {'Tech': -98.61915331107039, 'Sport': -142.75580463116978, 'Economy': -136.50720869904606})
# Predicted class: Tech
# Scores per class: defaultdict(<class 'float'>, {'Tech': -181.7136124136816, 'Sport': -258.8475140125075, 'Economy': -227.797673717665})
# Predicted class: Tech
# Scores per class: defaultdict(<class 'float'>, {'Tech': -145.86062842773606, 'Sport': -167.67594330801722, 'Economy': -130.35386075839529})
# Predicted class: Economy
# Scores per class: defaultdict(<class 'float'>, {'Tech': -196.8480772432411, 'Sport': -129.82274609672208, 'Economy': -202.4406404299633})
# Predicted class: Sport
# Scores per class: defaultdict(<class 'float'>, {'Tech': -177.91883151095632, 'Sport': -184.69341827406535, 'Economy': -146.99664298109923})
# Predicted class: Economy
# Scores per class: defaultdict(<class 'float'>, {'Tech': -189.0418856421268, 'Sport': -136.631927194823, 'Economy': -199.61602715072945})
# Predicted class: Sport
# Scores per class: defaultdict(<class 'float'>, {'Tech': -179.61998260148022, 'Sport': -213.37202936272013, 'Economy': -175.0482181292627})
# Predicted class: Economy
# Scores per class: defaultdict(<class 'float'>, {'Tech': -204.59781654553646, 'Sport': -122.83784327887894, 'Economy': -202.52845529573952})
# Predicted class: Sport
# Scores per class: defaultdict(<class 'float'>, {'Tech': -122.68843963261587, 'Sport': -134.03762755982893, 'Economy': -109.74707656941429})
# Predicted class: Economy
# Scores per class: defaultdict(<class 'float'>, {'Tech': -134.1140992706296, 'Sport': -93.39002259549724, 'Economy': -131.92138286752512})
# Predicted class: Sport
# Scores per class: defaultdict(<class 'float'>, {'Tech': -200.873680472398, 'Sport': -134.10614253923285, 'Economy': -188.97682176090876})
# Predicted class: Sport
# Scores per class: defaultdict(<class 'float'>, {'Tech': -124.59831014003778, 'Sport': -88.52664293270487, 'Economy': -124.18434693626077})
# Predicted class: Sport
# Scores per class: defaultdict(<class 'float'>, {'Tech': -120.1982063204058, 'Sport': -84.9148692565407, 'Economy': -117.4495161141399})
# Predicted class: Sport
# Scores per class: defaultdict(<class 'float'>, {'Tech': -93.2873258386243, 'Sport': -110.39593875332375, 'Economy': -78.28001033408428})
# Predicted class: Economy
# Scores per class: defaultdict(<class 'float'>, {'Tech': -185.66321570755835, 'Sport': -126.15937246785008, 'Economy': -190.32540957300017})
# Predicted class: Sport
# Scores per class: defaultdict(<class 'float'>, {'Tech': -97.371348999504, 'Sport': -55.90545552511172, 'Economy': -94.07067466854647})
# Predicted class: Sport
# Scores per class: defaultdict(<class 'float'>, {'Tech': -61.536591301797785, 'Sport': -83.49207999131653, 'Economy': -69.67444566569999})
# Predicted class: Tech
# Scores per class: defaultdict(<class 'float'>, {'Tech': -152.09822063644057, 'Sport': -194.4975637007129, 'Economy': -174.29613111171187})
# Predicted class: Tech
# Scores per class: defaultdict(<class 'float'>, {'Tech': -134.7810176733858, 'Sport': -186.78959913099703, 'Economy': -173.4206342867817})
# Predicted class: Tech
# Scores per class: defaultdict(<class 'float'>, {'Tech': -82.52257316785396, 'Sport': -51.87726887648361, 'Economy': -90.19182050749504})
# Predicted class: Sport
# Scores per class: defaultdict(<class 'float'>, {'Tech': -124.57399714782997, 'Sport': -180.09196265506785, 'Economy': -159.06624701681284})
# Predicted class: Tech
# Scores per class: defaultdict(<class 'float'>, {'Tech': -140.15404553265685, 'Sport': -214.88819148509086, 'Economy': -156.40048143557095})
# Predicted class: Tech
# Scores per class: defaultdict(<class 'float'>, {'Tech': -126.36368549560976, 'Sport': -92.6694866919, 'Economy': -133.53159506247758})
# Predicted class: Sport
# Scores per class: defaultdict(<class 'float'>, {'Tech': -111.02699950872888, 'Sport': -133.88512236373643, 'Economy': -125.8173624733527})
# Predicted class: Tech
# Scores per class: defaultdict(<class 'float'>, {'Tech': -164.38343823081922, 'Sport': -244.92752214512615, 'Economy': -183.31201767638754})
# Predicted class: Tech
# Scores per class: defaultdict(<class 'float'>, {'Tech': -126.47385683998137, 'Sport': -82.23473043355075, 'Economy': -130.54535207854437})
# Predicted class: Sport
# Scores per class: defaultdict(<class 'float'>, {'Tech': -133.48630583225673, 'Sport': -84.24131625291352, 'Economy': -131.64433503978847})
# Predicted class: Sport
# Scores per class: defaultdict(<class 'float'>, {'Tech': -170.39420488374896, 'Sport': -165.94472350753563, 'Economy': -138.76393728971672})
# Predicted class: Economy
# Scores per class: defaultdict(<class 'float'>, {'Tech': -178.58421840366995, 'Sport': -174.28682741503084, 'Economy': -133.60276186350717})
# Predicted class: Economy
# Scores per class: defaultdict(<class 'float'>, {'Tech': -153.01113618744606, 'Sport': -196.78063008192495, 'Economy': -128.43488000827293})
# Predicted class: Economy
# Scores per class: defaultdict(<class 'float'>, {'Tech': -90.12432524639404, 'Sport': -125.36077874358806, 'Economy': -112.98763344425979})
# Predicted class: Tech
# Scores per class: defaultdict(<class 'float'>, {'Tech': -73.09384588575955, 'Sport': -111.62802255707847, 'Economy': -86.6507295817053})
# Predicted class: Tech
# Scores per class: defaultdict(<class 'float'>, {'Tech': -91.36216828657058, 'Sport': -127.55966419542592, 'Economy': -118.53804898410522})
# Predicted class: Tech
# Scores per class: defaultdict(<class 'float'>, {'Tech': -125.12526458144175, 'Sport': -139.6935528457185, 'Economy': -113.83434291837152})
# Predicted class: Economy
# Scores per class: defaultdict(<class 'float'>, {'Tech': -77.79796769848724, 'Sport': -105.34041084268802, 'Economy': -93.78859995064128})
# Predicted class: Tech
# Scores per class: defaultdict(<class 'float'>, {'Tech': -111.99863186742846, 'Sport': -150.96473690517772, 'Economy': -149.3645773682445})
# Predicted class: Tech
# Scores per class: defaultdict(<class 'float'>, {'Tech': -102.0572062338373, 'Sport': -140.3322910782652, 'Economy': -103.58430044892334})
# Predicted class: Tech
# Scores per class: defaultdict(<class 'float'>, {'Tech': -197.02315413689894, 'Sport': -116.73341352656583, 'Economy': -202.01586884298214})
# Predicted class: Sport
# Scores per class: defaultdict(<class 'float'>, {'Tech': -118.58926222565174, 'Sport': -146.41821508006768, 'Economy': -94.76884826103415})
# Predicted class: Economy
# Scores per class: defaultdict(<class 'float'>, {'Tech': -210.8613164821519, 'Sport': -154.08613869006876, 'Economy': -201.7964803061379})
# Predicted class: Sport
# Scores per class: defaultdict(<class 'float'>, {'Tech': -152.45406453691058, 'Sport': -201.53656645240673, 'Economy': -149.1677918202157})
# Predicted class: Economy
# Scores per class: defaultdict(<class 'float'>, {'Tech': -75.63355141677951, 'Sport': -116.67277556311255, 'Economy': -92.65305363576724})
# Predicted class: Tech
# Scores per class: defaultdict(<class 'float'>, {'Tech': -220.94133365522862, 'Sport': -251.84987367612635, 'Economy': -166.74522142778596})
# Predicted class: Economy
# Scores per class: defaultdict(<class 'float'>, {'Tech': -73.09384588575955, 'Sport': -111.62802255707847, 'Economy': -86.6507295817053})
# Predicted class: Tech
# Scores per class: defaultdict(<class 'float'>, {'Tech': -149.4165743629432, 'Sport': -95.74422516155524, 'Economy': -148.0547948842415})
# Predicted class: Sport
# Scores per class: defaultdict(<class 'float'>, {'Tech': -90.65531706037075, 'Sport': -128.51550309371612, 'Economy': -124.26456903987399})
# Predicted class: Tech
# Scores per class: defaultdict(<class 'float'>, {'Tech': -195.48222432331042, 'Sport': -141.3261508519059, 'Economy': -199.19921921437015})
# Predicted class: Sport
# Scores per class: defaultdict(<class 'float'>, {'Tech': -242.39161507730384, 'Sport': -155.4663954936093, 'Economy': -241.319424868079})
# Predicted class: Sport
# Scores per class: defaultdict(<class 'float'>, {'Tech': -93.14921365373827, 'Sport': -130.67662132867173, 'Economy': -84.20757680335954})
# Predicted class: Economy
# Scores per class: defaultdict(<class 'float'>, {'Tech': -116.43750158866939, 'Sport': -68.37608645564362, 'Economy': -114.35602458092184})
# Predicted class: Sport
# Scores per class: defaultdict(<class 'float'>, {'Tech': -125.54846271525226, 'Sport': -141.7959259725788, 'Economy': -106.91063132258769})
# Predicted class: Economy
# Scores per class: defaultdict(<class 'float'>, {'Tech': -116.94186046978685, 'Sport': -120.72013165839152, 'Economy': -91.39079800314472})
# Predicted class: Economy
# Scores per class: defaultdict(<class 'float'>, {'Tech': -114.50610542643336, 'Sport': -132.12765473103497, 'Economy': -98.0271806936857})
# Predicted class: Economy
# Scores per class: defaultdict(<class 'float'>, {'Tech': -160.79085442305234, 'Sport': -188.71102982849064, 'Economy': -140.31942338888854})
# Predicted class: Economy
# Scores per class: defaultdict(<class 'float'>, {'Tech': -158.72625912091462, 'Sport': -221.89833639623168, 'Economy': -209.61572717383217})
# Predicted class: Tech
# Scores per class: defaultdict(<class 'float'>, {'Tech': -179.89737442558192, 'Sport': -133.32603481992138, 'Economy': -195.47085219305072})
# Predicted class: Sport
# Scores per class: defaultdict(<class 'float'>, {'Tech': -133.10016169000477, 'Sport': -178.4071667033719, 'Economy': -170.95833898441003})
# Predicted class: Tech
# Scores per class: defaultdict(<class 'float'>, {'Tech': -177.5637283088091, 'Sport': -107.6816401298803, 'Economy': -178.33036401440017})
# Predicted class: Sport
# Scores per class: defaultdict(<class 'float'>, {'Tech': -169.4253564076583, 'Sport': -200.21603953226875, 'Economy': -149.84068319967227})
# Predicted class: Economy
# Scores per class: defaultdict(<class 'float'>, {'Tech': -158.3917582901632, 'Sport': -185.13551036816995, 'Economy': -139.34656173060932})
# Predicted class: Economy
# Scores per class: defaultdict(<class 'float'>, {'Tech': -109.36080258011137, 'Sport': -76.48912724895852, 'Economy': -112.06207242118528})
# Predicted class: Sport
# Scores per class: defaultdict(<class 'float'>, {'Tech': -152.49415409476018, 'Sport': -219.16575470102453, 'Economy': -165.1420382762084})
# Predicted class: Tech
# Scores per class: defaultdict(<class 'float'>, {'Tech': -130.8197004891827, 'Sport': -98.20463315141632, 'Economy': -141.52461539200868})
# Predicted class: Sport
# Scores per class: defaultdict(<class 'float'>, {'Tech': -137.18265931764233, 'Sport': -105.14957561893864, 'Economy': -142.02134825764585})
# Predicted class: Sport
# Scores per class: defaultdict(<class 'float'>, {'Tech': -136.5393721352247, 'Sport': -174.63584483595548, 'Economy': -167.08775762662978})
# Predicted class: Tech
# Scores per class: defaultdict(<class 'float'>, {'Tech': -112.52268847718241, 'Sport': -142.5223843197799, 'Economy': -145.62969621987406})
# Predicted class: Tech
# Scores per class: defaultdict(<class 'float'>, {'Tech': -138.38951649595856, 'Sport': -149.26284317198872, 'Economy': -103.87896299906824})
# Predicted class: Economy
# Scores per class: defaultdict(<class 'float'>, {'Tech': -127.29903161744528, 'Sport': -143.89321089587386, 'Economy': -90.88823077889994})
# Predicted class: Economy
# Scores per class: defaultdict(<class 'float'>, {'Tech': -133.9391873089723, 'Sport': -92.61347074062417, 'Economy': -132.10017580856965})
# Predicted class: Sport
# Scores per class: defaultdict(<class 'float'>, {'Tech': -100.74859498872686, 'Sport': -120.21801285972657, 'Economy': -82.70355510818098})
# Predicted class: Economy
# Scores per class: defaultdict(<class 'float'>, {'Tech': -189.5064549227601, 'Sport': -142.77549783919045, 'Economy': -171.92628271911772})
# Predicted class: Sport
# Scores per class: defaultdict(<class 'float'>, {'Tech': -146.75696638207842, 'Sport': -183.93552739762416, 'Economy': -122.9975008602407})
# Predicted class: Economy
# Scores per class: defaultdict(<class 'float'>, {'Tech': -86.71111258620776, 'Sport': -116.36491072235427, 'Economy': -110.7616379469974})
# Predicted class: Tech
# Scores per class: defaultdict(<class 'float'>, {'Tech': -118.93313511590523, 'Sport': -80.98926204214735, 'Economy': -126.28259780989808})
# Predicted class: Sport
# Scores per class: defaultdict(<class 'float'>, {'Tech': -139.68790900132507, 'Sport': -90.28778250263579, 'Economy': -150.4631121334838})
# Predicted class: Sport
# Scores per class: defaultdict(<class 'float'>, {'Tech': -136.47979387486552, 'Sport': -227.1407648128935, 'Economy': -166.95915449500635})
# Predicted class: Tech
# Scores per class: defaultdict(<class 'float'>, {'Tech': -157.4547247441843, 'Sport': -114.92292906053534, 'Economy': -164.47661395542937})
# Predicted class: Sport
# Scores per class: defaultdict(<class 'float'>, {'Tech': -128.55724603012203, 'Sport': -181.08389967209746, 'Economy': -140.9401088853156})
# Predicted class: Tech
# Scores per class: defaultdict(<class 'float'>, {'Tech': -94.1595750642884, 'Sport': -60.27903473354345, 'Economy': -101.75915595507362})
# Predicted class: Sport
# Scores per class: defaultdict(<class 'float'>, {'Tech': -146.02445632985743, 'Sport': -96.57889229198798, 'Economy': -155.0026167223551})
# Predicted class: Sport
# Scores per class: defaultdict(<class 'float'>, {'Tech': -96.4382990145895, 'Sport': -119.7682491921184, 'Economy': -84.24449001794079})
# Predicted class: Economy
# Scores per class: defaultdict(<class 'float'>, {'Tech': -107.24437206589333, 'Sport': -143.52042439919995, 'Economy': -98.53128448605725})
# Predicted class: Economy
# Scores per class: defaultdict(<class 'float'>, {'Tech': -93.979512067471, 'Sport': -97.94203836017418, 'Economy': -79.17831069592874})
# Predicted class: Economy
# Scores per class: defaultdict(<class 'float'>, {'Tech': -100.7453185656673, 'Sport': -75.7945087438155, 'Economy': -107.683220748763})
# Predicted class: Sport
# Scores per class: defaultdict(<class 'float'>, {'Tech': -128.1459404726571, 'Sport': -87.21861613246803, 'Economy': -132.8295695794538})
# Predicted class: Sport
# Scores per class: defaultdict(<class 'float'>, {'Tech': -97.23012024010544, 'Sport': -142.40420511110204, 'Economy': -133.69320210810397})
# Predicted class: Tech
# Scores per class: defaultdict(<class 'float'>, {'Tech': -165.8609725990084, 'Sport': -221.88449285888439, 'Economy': -208.78099834619766})
# Predicted class: Tech
# Scores per class: defaultdict(<class 'float'>, {'Tech': -88.27569346098079, 'Sport': -55.314281090226395, 'Economy': -99.23353046794834})
# Predicted class: Sport
# Scores per class: defaultdict(<class 'float'>, {'Tech': -125.36759731769872, 'Sport': -77.63557778733843, 'Economy': -129.13013874241685})
# Predicted class: Sport
# Scores per class: defaultdict(<class 'float'>, {'Tech': -81.20197600401958, 'Sport': -84.31092153994179, 'Economy': -60.507563159949775})
# Predicted class: Economy
# Scores per class: defaultdict(<class 'float'>, {'Tech': -104.73638002757774, 'Sport': -147.38621203011206, 'Economy': -129.73237318524454})
# Predicted class: Tech
# Scores per class: defaultdict(<class 'float'>, {'Tech': -88.56748093697598, 'Sport': -54.07577846189666, 'Economy': -90.6432213484286})
# Predicted class: Sport
# Scores per class: defaultdict(<class 'float'>, {'Tech': -100.02067811298029, 'Sport': -63.31355740768243, 'Economy': -96.25154438961059})
# Predicted class: Sport
# Scores per class: defaultdict(<class 'float'>, {'Tech': -132.90793853258083, 'Sport': -79.76550906873388, 'Economy': -140.90318913702345})
# Predicted class: Sport
# ...
# Predicted class: Sport
# Scores per class: defaultdict(<class 'float'>, {'Tech': -122.01931717125234, 'Sport': -180.47219246863818, 'Economy': -164.3209267220474})
# Predicted class: Tech
# Scores per class: defaultdict(<class 'float'>, {'Tech': -117.77671049590867, 'Sport': -95.69445032651889, 'Economy': -119.0547895898033})
# Predicted class: Sport
# Scores per class: defaultdict(<class 'float'>, {'Tech': -178.3351634446811, 'Sport': -122.12896727038301, 'Economy': -188.79009511076248})
# Predicted class: Sport
# Scores per class: defaultdict(<class 'float'>, {'Tech': -95.81574505433353, 'Sport': -66.90207620939998, 'Economy': -106.84725123593162})
# Predicted class: Sport
# Scores per class: defaultdict(<class 'float'>, {'Tech': -131.60674652503704, 'Sport': -75.73161612635684, 'Economy': -130.45671386883512})
# Predicted class: Sport
# Scores per class: defaultdict(<class 'float'>, {'Tech': -109.98829587724423, 'Sport': -111.05313079343411, 'Economy': -93.78378048699895})
# Predicted class: Economy
# Scores per class: defaultdict(<class 'float'>, {'Tech': -59.823212301629304, 'Sport': -58.74611774297951, 'Economy': -45.25597043685462})
# Predicted class: Economy
# Scores per class: defaultdict(<class 'float'>, {'Tech': -76.37394324452187, 'Sport': -78.26661134537906, 'Economy': -56.70107212840847})
# Predicted class: Economy
# Scores per class: defaultdict(<class 'float'>, {'Tech': -143.07086152983493, 'Sport': -117.93259497557827, 'Economy': -137.21658813327247})
# Predicted class: Sport
# Scores per class: defaultdict(<class 'float'>, {'Tech': -136.47979387486552, 'Sport': -227.1407648128935, 'Economy': -166.95915449500635})
# Predicted class: Tech
# Scores per class: defaultdict(<class 'float'>, {'Tech': -104.50069224791207, 'Sport': -143.55395636126136, 'Economy': -136.04681590043515})
# Predicted class: Tech
# Scores per class: defaultdict(<class 'float'>, {'Tech': -182.93824354505924, 'Sport': -220.45275801529272, 'Economy': -155.76375727208352})
# Predicted class: Economy
# Scores per class: defaultdict(<class 'float'>, {'Tech': -134.08868959849372, 'Sport': -167.6086847789088, 'Economy': -119.98536782380573})
# Predicted class: Economy
# Scores per class: defaultdict(<class 'float'>, {'Tech': -146.51447469715737, 'Sport': -162.98256417448326, 'Economy': -103.73844842705033})
# Predicted class: Economy
# Scores per class: defaultdict(<class 'float'>, {'Tech': -134.50396216442414, 'Sport': -151.4632259015067, 'Economy': -92.96090749878618})
# Predicted class: Economy
# Scores per class: defaultdict(<class 'float'>, {'Tech': -118.61615276042416, 'Sport': -150.53702177947147, 'Economy': -117.21110393102813})
# Predicted class: Economy
# Scores per class: defaultdict(<class 'float'>, {'Tech': -143.7259194088657, 'Sport': -206.94022369529117, 'Economy': -181.4608062114954})
# Predicted class: Tech
# Scores per class: defaultdict(<class 'float'>, {'Tech': -95.65715970053465, 'Sport': -114.02559695883201, 'Economy': -85.87523468322509})
# Predicted class: Economy
# Scores per class: defaultdict(<class 'float'>, {'Tech': -143.7259194088657, 'Sport': -206.94022369529117, 'Economy': -181.4608062114954})
# Predicted class: Tech
# Scores per class: defaultdict(<class 'float'>, {'Tech': -114.75752239060682, 'Sport': -141.34132123545405, 'Economy': -122.69440129651906})
# Predicted class: Tech
# Scores per class: defaultdict(<class 'float'>, {'Tech': -94.78400546352135, 'Sport': -101.23158978099524, 'Economy': -78.61522147201653})
# Predicted class: Economy
# Scores per class: defaultdict(<class 'float'>, {'Tech': -154.88243932581221, 'Sport': -211.6735575202024, 'Economy': -212.55080893861586})
# Predicted class: Tech
# Scores per class: defaultdict(<class 'float'>, {'Tech': -141.13939815495587, 'Sport': -110.2546838541453, 'Economy': -147.73379639138778})
# Predicted class: Sport
# Scores per class: defaultdict(<class 'float'>, {'Tech': -187.41639108088717, 'Sport': -135.39815270897535, 'Economy': -181.18941408956792})
# Predicted class: Sport
# Scores per class: defaultdict(<class 'float'>, {'Tech': -136.40623731687737, 'Sport': -171.4874105387338, 'Economy': -153.87890595341378})
# Predicted class: Tech
# Scores per class: defaultdict(<class 'float'>, {'Tech': -118.67877863266139, 'Sport': -173.7301136147293, 'Economy': -146.6766611187607})
# Predicted class: Tech
# Scores per class: defaultdict(<class 'float'>, {'Tech': -142.984831362297, 'Sport': -84.08821899406621, 'Economy': -147.8245982060337})
# Predicted class: Sport
# Scores per class: defaultdict(<class 'float'>, {'Tech': -135.79096728668682, 'Sport': -192.48835135185792, 'Economy': -171.49663593418782})
# Predicted class: Tech
# Scores per class: defaultdict(<class 'float'>, {'Tech': -109.22329437727487, 'Sport': -68.13618279444974, 'Economy': -108.04481878550155})
# Predicted class: Sport
# Scores per class: defaultdict(<class 'float'>, {'Tech': -163.23434789546315, 'Sport': -110.95106154904909, 'Economy': -162.47518592391702})
# Predicted class: Sport
# Scores per class: defaultdict(<class 'float'>, {'Tech': -196.35494992270654, 'Sport': -214.2669161264597, 'Economy': -165.68026213500656})
# Predicted class: Economy
# Scores per class: defaultdict(<class 'float'>, {'Tech': -126.70534506879191, 'Sport': -171.97488371454918, 'Economy': -113.1541018158635})
# Predicted class: Economy
# Scores per class: defaultdict(<class 'float'>, {'Tech': -129.02205351892565, 'Sport': -81.29126688458638, 'Economy': -120.81689548873686})
# Predicted class: Sport
# Scores per class: defaultdict(<class 'float'>, {'Tech': -180.02570401926806, 'Sport': -225.0284298520231, 'Economy': -183.4697005852097})
# Predicted class: Tech
# Scores per class: defaultdict(<class 'float'>, {'Tech': -109.9409402635058, 'Sport': -156.87761146416472, 'Economy': -128.82781751663137})
# Predicted class: Tech
# Scores per class: defaultdict(<class 'float'>, {'Tech': -127.20046822893326, 'Sport': -153.16226959208464, 'Economy': -104.69762372795478})
# Predicted class: Economy
# Scores per class: defaultdict(<class 'float'>, {'Tech': -94.98089318706363, 'Sport': -64.54496788594622, 'Economy': -99.14529472711986})
# Predicted class: Sport
# Scores per class: defaultdict(<class 'float'>, {'Tech': -101.61658846556352, 'Sport': -67.5651294999154, 'Economy': -101.49088134930723})
# Predicted class: Sport
# Scores per class: defaultdict(<class 'float'>, {'Tech': -138.18053863218444, 'Sport': -187.21275290794915, 'Economy': -164.69594823210872})
# Predicted class: Tech
# Scores per class: defaultdict(<class 'float'>, {'Tech': -111.68751057414778, 'Sport': -162.04310002950018, 'Economy': -131.13063730835034})
# Predicted class: Tech
# Scores per class: defaultdict(<class 'float'>, {'Tech': -137.18265931764233, 'Sport': -105.14957561893864, 'Economy': -142.02134825764585})
# Predicted class: Sport
# Scores per class: defaultdict(<class 'float'>, {'Tech': -99.04508315642906, 'Sport': -137.86760266703993, 'Economy': -111.94999730870694})
# Predicted class: Tech
# Scores per class: defaultdict(<class 'float'>, {'Tech': -117.02963814125022, 'Sport': -123.55230056786405, 'Economy': -95.06459002764102})
# Predicted class: Economy
# Scores per class: defaultdict(<class 'float'>, {'Tech': -180.4477923401852, 'Sport': -197.792965693651, 'Economy': -147.787624524541})
# Predicted class: Economy
# Scores per class: defaultdict(<class 'float'>, {'Tech': -203.07740426725655, 'Sport': -141.17477888721285, 'Economy': -208.09691702693027})
# Predicted class: Sport
# Scores per class: defaultdict(<class 'float'>, {'Tech': -147.1222521180395, 'Sport': -109.39231425494651, 'Economy': -140.12030797978923})
# Predicted class: Sport
# Scores per class: defaultdict(<class 'float'>, {'Tech': -134.5582765282703, 'Sport': -149.28707614489963, 'Economy': -115.04377664197142})
# Predicted class: Economy
# Scores per class: defaultdict(<class 'float'>, {'Tech': -229.35291721752782, 'Sport': -244.60941407203526, 'Economy': -192.20403119290307})
# Predicted class: Economy
# Scores per class: defaultdict(<class 'float'>, {'Tech': -97.44073749830007, 'Sport': -67.28082994999302, 'Economy': -101.03994593413725})
# Predicted class: Sport
# Scores per class: defaultdict(<class 'float'>, {'Tech': -190.01005064214036, 'Sport': -145.6226750450292, 'Economy': -188.33419881682124})
# Predicted class: Sport
# Scores per class: defaultdict(<class 'float'>, {'Tech': -136.48348652839414, 'Sport': -90.52550903921036, 'Economy': -142.71005532955655})
# Predicted class: Sport
# Scores per class: defaultdict(<class 'float'>, {'Tech': -135.71101618989695, 'Sport': -159.0675689111494, 'Economy': -164.671485687998})
# Predicted class: Tech
# Scores per class: defaultdict(<class 'float'>, {'Tech': -94.08751838285951, 'Sport': -53.82943847169874, 'Economy': -96.12155311870865})
# Predicted class: Sport
# Scores per class: defaultdict(<class 'float'>, {'Tech': -193.0803286252995, 'Sport': -221.1541674349232, 'Economy': -158.62000800853457})
# Predicted class: Economy
# Scores per class: defaultdict(<class 'float'>, {'Tech': -126.28944381050957, 'Sport': -77.44905571669082, 'Economy': -130.90645569896336})
# Predicted class: Sport
# Scores per class: defaultdict(<class 'float'>, {'Tech': -94.52404639198812, 'Sport': -109.78106702305803, 'Economy': -80.73606605649404})
# Predicted class: Economy
# Scores per class: defaultdict(<class 'float'>, {'Tech': -88.12371430606447, 'Sport': -96.545941572798, 'Economy': -76.14955593309409})
# Predicted class: Economy
# Scores per class: defaultdict(<class 'float'>, {'Tech': -224.07297983686803, 'Sport': -171.27689043224345, 'Economy': -227.72223918122657})
# Predicted class: Sport
# Scores per class: defaultdict(<class 'float'>, {'Tech': -133.48515542291523, 'Sport': -159.42397300972604, 'Economy': -104.15001090301672})
# Predicted class: Economy
# Scores per class: defaultdict(<class 'float'>, {'Tech': -131.4501780768841, 'Sport': -177.9072040250112, 'Economy': -169.7581321427852})
# Predicted class: Tech
# Scores per class: defaultdict(<class 'float'>, {'Tech': -192.9293172693654, 'Sport': -214.82599983591973, 'Economy': -134.4001825018949})
# Predicted class: Economy
# Scores per class: defaultdict(<class 'float'>, {'Tech': -134.1140992706296, 'Sport': -93.39002259549724, 'Economy': -131.92138286752512})
# Predicted class: Sport
# Scores per class: defaultdict(<class 'float'>, {'Tech': -77.82807093129452, 'Sport': -102.66046678527233, 'Economy': -100.43288945022164})
# Predicted class: Tech
# Scores per class: defaultdict(<class 'float'>, {'Tech': -138.95590968226492, 'Sport': -167.12464196754567, 'Economy': -154.0453801141262})
# Predicted class: Tech
# Scores per class: defaultdict(<class 'float'>, {'Tech': -96.46544182075334, 'Sport': -105.5453555077112, 'Economy': -80.25489505088896})
# Predicted class: Economy
# Scores per class: defaultdict(<class 'float'>, {'Tech': -135.85757118531166, 'Sport': -187.2927206454212, 'Economy': -181.89417941148398})
# Predicted class: Tech
# Scores per class: defaultdict(<class 'float'>, {'Tech': -128.5189777046211, 'Sport': -86.2791333308832, 'Economy': -133.12712556331863})
# Predicted class: Sport
# Scores per class: defaultdict(<class 'float'>, {'Tech': -175.61378486680925, 'Sport': -129.9636696532601, 'Economy': -176.55814625344001})
# Predicted class: Sport
# Scores per class: defaultdict(<class 'float'>, {'Tech': -180.0718609782908, 'Sport': -109.6682275595643, 'Economy': -188.53775223883537})
# Predicted class: Sport
# Scores per class: defaultdict(<class 'float'>, {'Tech': -153.54737644572666, 'Sport': -176.71021986059026, 'Economy': -124.69785707491054})
# Predicted class: Economy
# Scores per class: defaultdict(<class 'float'>, {'Tech': -134.25393493188685, 'Sport': -153.42303956443277, 'Economy': -116.21316567688767})
# Predicted class: Economy
# Scores per class: defaultdict(<class 'float'>, {'Tech': -84.83339324005965, 'Sport': -60.11154556662603, 'Economy': -92.17186712437675})
# Predicted class: Sport
# Scores per class: defaultdict(<class 'float'>, {'Tech': -141.325681517561, 'Sport': -179.16256402263159, 'Economy': -169.04369572359926})
# Predicted class: Tech
# Scores per class: defaultdict(<class 'float'>, {'Tech': -136.12792340377084, 'Sport': -81.00538527425573, 'Economy': -146.1700670357314})
# Predicted class: Sport
# Scores per class: defaultdict(<class 'float'>, {'Tech': -130.6612410711026, 'Sport': -87.28161838014897, 'Economy': -142.130177719248})
# Predicted class: Sport
# Scores per class: defaultdict(<class 'float'>, {'Tech': -154.78484381189867, 'Sport': -102.37616344041626, 'Economy': -158.87062827285234})
# Predicted class: Sport
# Scores per class: defaultdict(<class 'float'>, {'Tech': -104.76440389628523, 'Sport': -128.47557447809083, 'Economy': -115.30804607108631})
# Predicted class: Tech
# Scores per class: defaultdict(<class 'float'>, {'Tech': -208.15522346237853, 'Sport': -184.6144866584607, 'Economy': -199.4647653004867})
# Predicted class: Sport
# Scores per class: defaultdict(<class 'float'>, {'Tech': -121.705748131653, 'Sport': -167.84761350018965, 'Economy': -147.98417554056024})
# Predicted class: Tech
# Scores per class: defaultdict(<class 'float'>, {'Tech': -73.09384588575955, 'Sport': -111.62802255707847, 'Economy': -86.6507295817053})
# Predicted class: Tech
# Scores per class: defaultdict(<class 'float'>, {'Tech': -82.77349463660977, 'Sport': -88.66800687315371, 'Economy': -65.92196360026455})
# Predicted class: Economy
# Scores per class: defaultdict(<class 'float'>, {'Tech': -124.68654548003907, 'Sport': -79.13404105554285, 'Economy': -124.62551538731152})
# Predicted class: Sport
# Scores per class: defaultdict(<class 'float'>, {'Tech': -142.52860848286264, 'Sport': -179.47085902647652, 'Economy': -141.19846552529899})
# Predicted class: Economy
# Scores per class: defaultdict(<class 'float'>, {'Tech': -164.5643261048963, 'Sport': -99.23769587293512, 'Economy': -157.63742190262423})
# Predicted class: Sport
# Scores per class: defaultdict(<class 'float'>, {'Tech': -120.17822930415917, 'Sport': -182.1628074597371, 'Economy': -148.58615160899592})
# Predicted class: Tech
# Scores per class: defaultdict(<class 'float'>, {'Tech': -160.61357548453142, 'Sport': -192.02722451847075, 'Economy': -115.2159933786247})
# Predicted class: Economy
# Scores per class: defaultdict(<class 'float'>, {'Tech': -144.70981137285014, 'Sport': -197.518232853641, 'Economy': -176.24381795020182})
# Predicted class: Tech
# Scores per class: defaultdict(<class 'float'>, {'Tech': -102.12611414811879, 'Sport': -144.91977928302, 'Economy': -146.3922249324586})
# Predicted class: Tech
# Scores per class: defaultdict(<class 'float'>, {'Tech': -91.82531820145574, 'Sport': -51.48854958611335, 'Economy': -95.61924944654044})
# Predicted class: Sport
# Scores per class: defaultdict(<class 'float'>, {'Tech': -149.84274497332902, 'Sport': -116.78050312568084, 'Economy': -146.59468725672895})
# Predicted class: Sport
# Scores per class: defaultdict(<class 'float'>, {'Tech': -147.43957895500876, 'Sport': -103.86803224230903, 'Economy': -151.9780607748875})
# Predicted class: Sport
# Scores per class: defaultdict(<class 'float'>, {'Tech': -112.92320113882542, 'Sport': -170.88297775566687, 'Economy': -151.7035793350041})
# Predicted class: Tech
# Scores per class: defaultdict(<class 'float'>, {'Tech': -203.00227034950797, 'Sport': -207.68133002331015, 'Economy': -169.48218800471525})
# Predicted class: Economy
# Scores per class: defaultdict(<class 'float'>, {'Tech': -134.41859165952928, 'Sport': -93.98452756550986, 'Economy': -141.19318933936515})
# Predicted class: Sport
# Scores per class: defaultdict(<class 'float'>, {'Tech': -148.69755026871812, 'Sport': -164.70331162010694, 'Economy': -103.31976212199972})
# Predicted class: Economy
# Scores per class: defaultdict(<class 'float'>, {'Tech': -171.35697466619212, 'Sport': -128.2258762218051, 'Economy': -166.53177655594487})
# Predicted class: Sport
# Scores per class: defaultdict(<class 'float'>, {'Tech': -121.6068956481754, 'Sport': -137.44351812751228, 'Economy': -87.29869970321339})
# Predicted class: Economy
# Scores per class: defaultdict(<class 'float'>, {'Tech': -162.20733373646507, 'Sport': -210.475340762966, 'Economy': -189.87355529131688})
# Predicted class: Tech

# %%
classifier.evaluate(y_test, predicted_labels)
# Out:
# Confusion Matrix:
#  [[4978    0   16]
#  [   3 5036    1]
#  [  68    4 4902]]
# Accuracy: 0.9938699360341151
#               precision    recall  f1-score   support
#
#      Economy       0.99      1.00      0.99      4994
#        Sport       1.00      1.00      1.00      5040
#         Tech       1.00      0.99      0.99      4974
#
#     accuracy                           0.99     15008
#    macro avg       0.99      0.99      0.99     15008
# weighted avg       0.99      0.99      0.99     15008

# %%
results_df = pd.DataFrame({
    'Actual': y_test,
    'Predicted': predicted_labels,
    'Headline': X_test_clean
}).reset_index(drop=True)


misclassified = results_df[results_df['Actual'] != results_df['Predicted']]

classes = ['Sports', 'Tech', 'Economy']
misclassified_analysis = {}

for cls in classes:
    misclassified_cls = misclassified[misclassified['Actual'] == cls]
    samples = misclassified_cls.sample(n=min(5, len(misclassified_cls)), random_state=42)
    misclassified_analysis[cls] = samples

for cls, samples in misclassified_analysis.items():
    print(f"Misclassified samples for class '{cls}':")
    print(samples)
    print("\n")
# Out:
# Misclassified samples for class 'Sports':
# Empty DataFrame
# Columns: [Actual, Predicted, Headline]
# Index: []
#
#
# Misclassified samples for class 'Tech':
#       Actual Predicted                                           Headline
# 423     Tech   Economy  دولت لایحه بودجه سال درآمد حاصل نامبرینگ شماره...
# 12606   Tech   Economy  هزار کارت بانکی هفته فرآیند ثبت‌نام الکترونیکی...
# 3998    Tech   Economy  وزیر علوم تکیه فناوری می‌توانیم بازار جهانی بد...
# 62      Tech   Economy  رئیس کارگروه فناوری‌های پیشران اتاق بازرگانی ا...
# 5739    Tech     Sport  رئیس کمیته ملی ربوکاپ ایران برگزاری دومین دوره...
#
#
# Misclassified samples for class 'Economy':
#         Actual Predicted                                           Headline
# 296    Economy      Tech  مدیر توسعه کارآفرینی بهره‌وری نیروی کار وزارت ...
# 2731   Economy      Tech  مدیر توسعه کارآفرینی بهره‌وری نیروی کار وزارت ...
# 4563   Economy      Tech  معاون علمی فناوری رییس‌جمهور دنبال طراحی خودرو...
# 13347  Economy      Tech  رئیس موسسه تحقیقات آب ساخت رسوب سنج شناور همکا...
# 13225  Economy      Tech  رئیس موسسه تحقیقات آب ساخت رسوب سنج شناور همکا...
